# %% [markdown]
# #### 1. Import pandas library

# %%
import pandas as pd

# %% [markdown]
# #### 2. Import pymysql and sqlalchemy as you have learnt in the lesson of importing/exporting data

# %%
import pymysql
import sqlalchemy

# %% [markdown]
# #### 3. Create a mysql engine to set the connection to the server. Check the connection details in [this link](https://relational.fit.cvut.cz/search?tableCount%5B%5D=0-10&tableCount%5B%5D=10-30&dataType%5B%5D=Numeric&databaseSize%5B%5D=KB&databaseSize%5B%5D=MB)

# %%
# on utilise ça https://relational.fit.cvut.cz/dataset/Stats

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://guest:relational@relational.fit.cvut.cz/stats')

# %% [markdown]
# #### 4. Import the users table

# %%
# avec le sql du lien DATA
users1 = pd.read_sql_query('SELECT * FROM stats.users', engine)
users1.head()
users1= pd.read_sql_query('SELECT CreationDate FROM stats.users', engine)
users1.head()
# Out:
#          CreationDate
# 0 2010-07-19 06:55:26
# 1 2010-07-19 14:01:36
# 2 2010-07-19 15:34:50
# 3 2010-07-19 19:03:27
# 4 2010-07-19 19:03:57

# %%
# avec le csv USERS
users = pd.read_csv('/Users/helene/Desktop/helene/users_for_helene.csv')

# %%
users.head()
# Out:
#    Unnamed: 0  Id  Reputation         CreationDate   DisplayName  \
# 0           0  -1           1  2010-07-19 06:55:26     Community
# 1           1   2         101  2010-07-19 14:01:36  Geoff Dalgas
# 2           2   3         101  2010-07-19 15:34:50  Jarrod Dixon
# 3           3   4         101  2010-07-19 19:03:27        Emmett
# 4           4   5        6792  2010-07-19 19:03:57         Shane
#
#         LastAccessDate                      WebsiteUrl            Location  \
# 0  2010-07-19 06:55:26  http://meta.stackexchange.com/  on the server farm
# 1  2013-11-12 22:07:23        http://stackoverflow.com       Corvallis, OR
# 2  2014-08-08 06:42:58        http://stackoverflow.com        New York, NY
# 3  2014-01-02 09:31:02    http://minesweeperonline.com   San Francisco, CA
# 4  2014-08-13 00:23:47         http://www.statalgo.com        New York, NY
#
#                                              AboutMe  Views  UpVotes  \
# ...

# %% [markdown]
# #### 5. Rename Id column to userId

# %%
users.rename(columns={'Id':'userId'}, inplace=True)
users.head()
# Out:
#    Unnamed: 0  userId  Reputation         CreationDate   DisplayName  \
# 0           0      -1           1  2010-07-19 06:55:26     Community
# 1           1       2         101  2010-07-19 14:01:36  Geoff Dalgas
# 2           2       3         101  2010-07-19 15:34:50  Jarrod Dixon
# 3           3       4         101  2010-07-19 19:03:27        Emmett
# 4           4       5        6792  2010-07-19 19:03:57         Shane
#
#         LastAccessDate                      WebsiteUrl            Location  \
# 0  2010-07-19 06:55:26  http://meta.stackexchange.com/  on the server farm
# 1  2013-11-12 22:07:23        http://stackoverflow.com       Corvallis, OR
# 2  2014-08-08 06:42:58        http://stackoverflow.com        New York, NY
# 3  2014-01-02 09:31:02    http://minesweeperonline.com   San Francisco, CA
# 4  2014-08-13 00:23:47         http://www.statalgo.com        New York, NY
#
#                                              AboutMe  Views  UpVotes  \
# ...

# %% [markdown]
# #### 6. Import the posts table.

# %%
posts = pd.read_csv('/Users/helene/Desktop/helene/posts_for_helene.csv')

# %% [markdown]
# #### 7. Rename Id column to postId and OwnerUserId to userId

# %%
posts.rename(columns={'Id':'postId',"OwnerUserId":"userId"})
posts.head()
# Out:
#    Unnamed: 0  postId  PostTypeId  AcceptedAnswerId          CreaionDate  \
# 0           0       1           1              15.0  2010-07-19 19:12:12
# 1           1       2           1              59.0  2010-07-19 19:12:57
# 2           2       3           1               5.0  2010-07-19 19:13:28
# 3           3       4           1             135.0  2010-07-19 19:13:31
# 4           4       5           2               NaN  2010-07-19 19:14:43
#
#    Score  ViewCount                                               Body  \
# 0     23     1278.0  <p>How should I elicit prior distributions fro...
# 1     22     8198.0  <p>In many different statistical methods there...
# 2     54     3613.0  <p>What are some valuable Statistical Analysis...
# 3     13     5224.0  <p>I have two groups of data.  Each with a dif...
# 4     81        NaN  <p>The R-project</p>\n\n<p><a href="http://www...
#
#    userId      LasActivityDate  ... AnswerCount CommentCount  FavoriteCount  \
# ...

# %% [markdown]
# #### 8. Define new dataframes for users and posts with the following selected columns:
#     **users columns**: userId, Reputation,Views,UpVotes,DownVotes
#     **posts columns**: postId, Score,userID,ViewCount,CommentCount

# %%
users2=users[['userId', 'Reputation', 'Views', 'UpVotes', 'DownVotes']]
users2.head()
# Out:
#    userId  Reputation  Views  UpVotes  DownVotes
# 0      -1           1      0     5007       1920
# 1       2         101     25        3          0
# 2       3         101     22       19          0
# 3       4         101     11        0          0
# 4       5        6792   1145      662          5

# %%
posts2=posts[['postId', 'Score', 'userId', 'ViewCount', 'CommentCount']]
posts2.head()
# Out:
#    postId  Score  userId  ViewCount  CommentCount
# 0       1     23     8.0     1278.0             1
# 1       2     22    24.0     8198.0             1
# 2       3     54    18.0     3613.0             4
# 3       4     13    23.0     5224.0             2
# 4       5     81    23.0        NaN             3

# %% [markdown]
# #### 8. Merge both dataframes, users and posts.
# You will need to make a [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) of posts and users dataframes.

# %%
merge_df=posts2.merge(users2, left_on='userId', right_on='userId')
merge_df
# Out:
#        postId  Score   userId  ViewCount  CommentCount  Reputation  Views  \
# 0           1     23      8.0     1278.0             1        6764   1089
# 1          16     16      8.0        NaN             3        6764   1089
# 2          36     41      8.0    67396.0             7        6764   1089
# 3          65     14      8.0        NaN             3        6764   1089
# 4          78     33      8.0        NaN             4        6764   1089
# 5         111      8      8.0        NaN             3        6764   1089
# 6         114     30      8.0     1220.0             1        6764   1089
# 7         129      4      8.0        NaN             0        6764   1089
# 8         142      5      8.0        NaN             0        6764   1089
# 9         168     17      8.0     1022.0             1        6764   1089
# 10        170     56      8.0     7733.0             1        6764   1089
# 11        254      4      8.0        NaN             3        6764   1089
# ...

# %% [markdown]
# #### 9. How many missing values do you have in your merged dataframe? On which columns?

# %%
print(merge_df.isnull().sum())
# Out:
# postId              0
# Score               0
# userId              0
# ViewCount       48396
# CommentCount        0
# Reputation          0
# Views               0
# UpVotes             0
# DownVotes           0
# dtype: int64

# %% [markdown]
# #### 10. You will need to make something with missing values.  Will you clean or filling them? Explain.
# **Remember** to check the results of your code before passing to the next step

# %%
# on peut les fill avec des 0 car

# %% [markdown]
# #### 11. Adjust the data types in order to avoid future issues. Which ones should be changed?

# %%
#score = float

# %% [markdown]
# #### Bonus: Identify extreme values in your merged dataframe as you have learned in class, create a dataframe called outliers with the same columns as our data set and calculate the bounds. The values of the outliers dataframe will be the values of the merged_df that fall outside that bounds. You will need to save your outliers dataframe to a csv file on your-code folder.
