# %% [markdown]
# # Parsing APIs Example

# %% [markdown]
# ## Intro
#
# Now we will take a look on a real data. When you parse data from web you will often meet API based web-pages.
#
# For example [zalando.fr](https://www.zalando.fr/accueil-homme/) is API based web-page.
#
# In this guided lab you will learn how to obtain the links from webpages and extract the data. Read through this doc, execute the cells in order and make sure you understand the explanations.
#
# *Note: This guided lab uses Google Chrome. Other browsers like Safari and Firefox have similar tools for developers but they work differently. To save your time in following this lab, it is strongly recommended that you install and use Google Chrome.*

# %% [markdown]
# ## Obtaining the link
#
# Zalando is discount e-store where you can buy clothes and accesories with discount. When we go to the web-page, we can choose different sections. First the general process will be shown using [Children section](https://www.zalando.fr/accueil-enfant/) as example.
#
# Here we will parse data about promotions only. Therefore, final output will be the DataFrame with all the goods under discount.
#
# [![Image from Gyazo](https://i.gyazo.com/fa4874d8e81c7570273bbfb853d66308.png)](https://gyazo.com/fa4874d8e81c7570273bbfb853d66308)
#
#
# We go to Promos page. Right click of mouse shows us a list of actions possible, from which we select Inspect.
#
# <img src='https://i.gyazo.com/bccbd11d69c9040dc98758d443e32052.png' width="400">
#
#
# You will see the menu dropdown on the right side or on the bottom of the window. There you should click on Network:
#
#
# [![Image from Gyazo](https://i.gyazo.com/f7e0db81cbfee67694183d1a7640bf81.png)](https://gyazo.com/f7e0db81cbfee67694183d1a7640bf81)

# %% [markdown]
# Right after the developer part will change showing the files behind the page. In order to obtain only useful files we select the following settings:
# 1. Preserve Log
# 2. Select XHR files.
#
# [![Image from Gyazo](https://i.gyazo.com/9a899d4441d9d93e795f79747f1e47d5.png)](https://gyazo.com/9a899d4441d9d93e795f79747f1e47d5)
#
# In order to obtain some files we need to scrool down and go forward to second page.
#
# [![Image from Gyazo](https://i.gyazo.com/0956eb3d5125075a236c9a439c7749c7.png)](https://gyazo.com/0956eb3d5125075a236c9a439c7749c7)
#
# In the Network panel you can see the following files being uploaded. All the data on the web-page is uploaded from the json file, which is one of the following. It is important to understand which file contains what kind of information.
#
# <a href="https://gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c"><img src="https://i.gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c.png" alt="Image from Gyazo" width="724.8"/></a>
#
# When you find what kind of information you need for the data to be uploaded you just test it. Here we need the article... file:
#
# <a href="https://gyazo.com/78b35bf492994b3f35c0564a21da202a"><img src="https://i.gyazo.com/78b35bf492994b3f35c0564a21da202a.png" alt="Image from Gyazo" width="727.2"/></a>
#
# When we test the link in Chrome inkognito mode we obtain the proper json file:
#
#
# <a href="https://gyazo.com/b60453fa98454fa29771c731a5174443"><img src="https://i.gyazo.com/b60453fa98454fa29771c731a5174443.png" alt="Image from Gyazo" width="1530.4"/></a>

# %% [markdown]
# In order to change the objects in the json file (kind of pagination), you need to change the offset (the number of the first element on the page). in fact, if you take a look on the link, it is easy to unerstand the structure of the link.
#
# # Reading the data
#
# Now the party rocks! When we know how can we obtain the data, it is not a problem to obtain the whole database with all the data from the web-page.
# In this lab you will collect your database of Zalando products. You select which goods you want to track. You can define as many filters to your data as you want. Just make sure that the data represents the filters.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
# Paste the url you obtained for your data
url='https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=84&sort=sale'

# %% [markdown]
# #### Collect first 84 object of the of the data (1st page)
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having *family_articles, flags, media* and *sizes* remaining lists (they are exceptions).

# %%
# Your code
header = {'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36'}


response = requests.get(url, headers = header)
results2 = response.json()
results2
# Out:
# {'total_count': 20260,
#  'pagination': {'page_count': 242, 'current_page': 242, 'per_page': 84},
#  'sort': 'sale',
#  'articles': [{'sku': 'N1486A00E-O11',
#    'name': 'Body - brown',
#    'price': {'original': '16,99\xa0€',
#     'promotional': '16,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['0m', '1m', '2m', '3m', '6m', '9m', '12m'],
#    'url_key': 'noppies-body-brown-n1486a00e-o11',
#    'media': [{'path': 'N1/48/6A/00/EO/11/N1486A00E-O11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Noppies',
#    'is_premium': False,
#    'family_articles': [{'sku': 'N1486A00E-O11',
#      'url_key': 'noppies-body-brown-n1486a00e-o11',
#      'media': [{'path': 'N1/48/6A/00/EO/11/N1486A00E-O11@7.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'Body - brown',
#      'sizes': ['0m', '1m', '2m', '3m', '6m', '9m', '12m'],
#      'price': {'original': '16,99\xa0€',
#       'promotional': '16,99\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'csr',
#        'value': 'Éco-responsable',
#        'tracking_value': 'sustainable'}]}],
#    'flags': [{'key': 'csr',
#      'value': 'Éco-responsable',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'underwear'},
#   {'sku': 'ES124G0I8-M11',
#    'name': 'Débardeur - soft green',
#    'price': {'original': '9,95\xa0€',
#     'promotional': '5,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2a', '8a'],
#    'url_key': 'esprit-debardeur-soft-green-es124g0i8-m11',
#    'media': [{'path': 'ES/12/4G/0I/8M/11/ES124G0I8-M11@6.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Esprit',
#    'is_premium': False,
#    'family_articles': [{'sku': 'ES124G0I8-M11',
#      'url_key': 'esprit-debardeur-soft-green-es124g0i8-m11',
#      'media': [{'path': 'ES/12/4G/0I/8M/11/ES124G0I8-M11@6.1.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'Débardeur - soft green',
#      'sizes': ['2a', '8a'],
#      'price': {'original': '9,95\xa0€',
#       'promotional': '5,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-50%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'PAJ24G00U-G11',
#    'name': 'TARUN - T-shirt imprimé - fiery red',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '22,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['10a'],
#    'url_key': 'paul-smith-junior-tarun-t-shirt-imprime-fiery-red-paj24g00u-g11',
#    'media': [{'path': 'PA/J2/4G/00/UG/11/PAJ24G00U-G11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Paul Smith Junior',
#    'is_premium': True,
#    'family_articles': [{'sku': 'PAJ24G00U-G11',
#      'url_key': 'paul-smith-junior-tarun-t-shirt-imprime-fiery-red-paj24g00u-g11',
#      'media': [{'path': 'PA/J2/4G/00/UG/11/PAJ24G00U-G11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'TARUN - T-shirt imprimé - fiery red',
#      'sizes': ['10a'],
#      'price': {'original': '54,95\xa0€',
#       'promotional': '22,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-60%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-60%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'PAJ24G00L-K11',
#    'name': 'TYSON - T-shirt imprimé - dark sapphire',
#    'price': {'original': '64,95\xa0€',
#     'promotional': '26,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['10a'],
#    'url_key': 'paul-smith-junior-tyson-t-shirt-imprime-dark-sapphire-paj24g00l-k11',
#    'media': [{'path': 'PA/J2/4G/00/LK/11/PAJ24G00L-K11@6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Paul Smith Junior',
#    'is_premium': True,
#    'family_articles': [{'sku': 'PAJ24G00L-K11',
#      'url_key': 'paul-smith-junior-tyson-t-shirt-imprime-dark-sapphire-paj24g00l-k11',
#      'media': [{'path': 'PA/J2/4G/00/LK/11/PAJ24G00L-K11@6.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'TYSON - T-shirt imprimé - dark sapphire',
#      'sizes': ['10a'],
#      'price': {'original': '64,95\xa0€',
#       'promotional': '26,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-60%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-60%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'NI114D058-A13',
#    'name': 'COURT BOROUGH - Baskets basses - white/black/wolf grey/anthracite/volt',
#    'price': {'original': '34,95\xa0€',
#     'promotional': '24,46\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['32'],
#    'url_key': 'nike-sportswear-court-borough-baskets-basses-ni114d058-a13',
#    'media': [{'path': 'NI/11/4D/05/8A/13/NI114D058-A13@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [{'sku': 'NI114D058-A13',
#      'url_key': 'nike-sportswear-court-borough-baskets-basses-ni114d058-a13',
#      'media': [{'path': 'NI/11/4D/05/8A/13/NI114D058-A13@16.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'COURT BOROUGH - Baskets basses - white/black/wolf grey/anthracite/volt',
#      'sizes': ['32'],
#      'price': {'original': '34,95\xa0€',
#       'promotional': '24,46\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'NI114D058-Q11',
#      'url_key': 'nike-sportswear-baskets-basses-black-ni114d058-q11',
#      'media': [{'path': 'NI/11/4D/05/8Q/11/NI114D058-Q11@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'COURT BOROUGH - Baskets basses - black',
#      'sizes': ['27.5',
#       '28',
#       '28.5',
#       '29.5',
#       '30',
#       '31',
#       '31.5',
#       '32',
#       '33',
#       '33.5',
#       '34',
#       '35'],
#      'price': {'original': '34,95\xa0€',
#       'promotional': '34,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []},
#     {'sku': 'NI114D058-A11',
#      'url_key': 'nike-sportswear-court-borough-baskets-basses-ni114d058-a11',
#      'media': [{'path': 'NI/11/4D/05/8A/11/NI114D058-A11@12.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'COURT BOROUGH - Baskets basses - white',
#      'sizes': ['27.5',
#       '28',
#       '28.5',
#       '29.5',
#       '30',
#       '31',
#       '31.5',
#       '32',
#       '33',
#       '33.5',
#       '34',
#       '35'],
#      'price': {'original': '34,95\xa0€',
#       'promotional': '34,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []},
#     {'sku': 'NI114D058-K11',
#      'url_key': 'nike-sportswear-court-borough-baskets-basses-ni114d058-k11',
#      'media': [{'path': 'NI/11/4D/05/8K/11/NI114D058-K11@8.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'COURT BOROUGH - Baskets basses - obsidian/white',
#      'sizes': ['33.5'],
#      'price': {'original': '34,95\xa0€',
#       'promotional': '34,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'RE323G01A-A11',
#    'name': 'T-shirt imprimé - optical white',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '12,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['8a'],
#    'url_key': 'replay-t-shirt-imprime-optical-white-re323g01a-a11',
#    'media': [{'path': 'RE/32/3G/01/AA/11/RE323G01A-A11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Replay',
#    'is_premium': False,
#    'family_articles': [{'sku': 'RE323G01A-A11',
#      'url_key': 'replay-t-shirt-imprime-optical-white-re323g01a-a11',
#      'media': [{'path': 'RE/32/3G/01/AA/11/RE323G01A-A11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'T-shirt imprimé - optical white',
#      'sizes': ['8a'],
#      'price': {'original': '29,95\xa0€',
#       'promotional': '12,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-60%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-60%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'LE224G065-Q11',
#    'name': 'TEE HERONEON - T-shirt imprimé - black',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '24,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['3a'],
#    'url_key': 'levisr-tee-heroneon-t-shirt-imprime-black-le224g065-q11',
#    'media': [{'path': 'LE/22/4G/06/5Q/11/LE224G065-Q11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [{'sku': 'LE224G065-Q11',
#      'url_key': 'levisr-tee-heroneon-t-shirt-imprime-black-le224g065-q11',
#      'media': [{'path': 'LE/22/4G/06/5Q/11/LE224G065-Q11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'TEE HERONEON - T-shirt imprimé - black',
#      'sizes': ['3a'],
#      'price': {'original': '29,95\xa0€',
#       'promotional': '24,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'HA113G008-J11',
#    'name': 'TOP MIX - Tongs - rose quartz/ice blue',
#    'price': {'original': '15,95\xa0€',
#     'promotional': '12,76\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['25/26'],
#    'url_key': 'havaianas-top-mix-tongs-rose-quartzice-blue-ha113g008-j11',
#    'media': [{'path': 'HA/11/3G/00/8J/11/HA113G008-J11@5.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Havaianas',
#    'is_premium': False,
#    'family_articles': [{'sku': 'HA113G008-J11',
#      'url_key': 'havaianas-top-mix-tongs-rose-quartzice-blue-ha113g008-j11',
#      'media': [{'path': 'HA/11/3G/00/8J/11/HA113G008-J11@9.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'TOP MIX - Tongs - rose quartz/ice blue',
#      'sizes': ['25/26'],
#      'price': {'original': '15,95\xa0€',
#       'promotional': '12,76\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'CJ223D0GM-Q11',
#    'name': 'BABY CARDI PANDA SET - Body - black',
#    'price': {'original': '23,95\xa0€',
#     'promotional': '10,78\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['6m'],
#    'url_key': 'carters-baby-cardi-panda-set-legging-black-cj223d0gm-q11',
#    'media': [{'path': 'CJ/22/3D/0G/MQ/11/CJ223D0GM-Q11@19.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': "Carter's",
#    'is_premium': False,
#    'family_articles': [{'sku': 'CJ223D0GM-Q11',
#      'url_key': 'carters-baby-cardi-panda-set-legging-black-cj223d0gm-q11',
#      'media': [{'path': 'CJ/22/3D/0G/MQ/11/CJ223D0GM-Q11@19.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'BABY CARDI PANDA SET - Body - black',
#      'sizes': ['6m'],
#      'price': {'original': '23,95\xa0€',
#       'promotional': '10,78\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-55%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-55%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'DO213I010-T11',
#    'name': '1460 GLITTER - Bottines à lacets - rainbow',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '45,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['22'],
#    'url_key': 'dr-martens-1460-glitter-bottines-a-lacets-rainbow-do213i010-t11',
#    'media': [{'path': 'DO/21/3I/01/0T/11/DO213I010-T11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Dr. Martens',
#    'is_premium': False,
#    'family_articles': [{'sku': 'DO213I010-T11',
#      'url_key': 'dr-martens-1460-glitter-bottines-a-lacets-rainbow-do213i010-t11',
#      'media': [{'path': 'DO/21/3I/01/0T/11/DO213I010-T11@10.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': '1460 GLITTER - Bottines à lacets - rainbow',
#      'sizes': ['22'],
#      'price': {'original': '89,95\xa0€',
#       'promotional': '45,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-50%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe'},
#   {'sku': 'LE224L01K-K11',
#    'name': 'ZIPPER - Veste de survêtement - dress blue',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '42,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['8a'],
#    'url_key': 'levisr-zipper-veste-de-survetement-dress-blue-le224l01k-k11',
#    'media': [{'path': 'LE/22/4L/01/KK/11/LE224L01K-K11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [{'sku': 'LE224L01K-K11',
#      'url_key': 'levisr-zipper-veste-de-survetement-dress-blue-le224l01k-k11',
#      'media': [{'path': 'LE/22/4L/01/KK/11/LE224L01K-K11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'ZIPPER - Veste de survêtement - dress blue',
#      'sizes': ['8a'],
#      'price': {'original': '69,95\xa0€',
#       'promotional': '42,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-40%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'SO224G0LF-A11',
#    'name': 'T-shirt à manches longues - white melange',
#    'price': {'original': '15,99\xa0€',
#     'promotional': '4,80\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['6-7axREG', '8-9axREG'],
#    'url_key': 'soliver-t-shirt-a-manches-longues-white-melange-so224g0lf-a11',
#    'media': [{'path': 'SO/22/4G/0L/FA/11/SO224G0LF-A11@4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 's.Oliver',
#    'is_premium': False,
#    'family_articles': [{'sku': 'SO224G0LF-A11',
#      'url_key': 'soliver-t-shirt-a-manches-longues-white-melange-so224g0lf-a11',
#      'media': [{'path': 'SO/22/4G/0L/FA/11/SO224G0LF-A11@4.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'T-shirt à manches longues - white melange',
#      'sizes': ['6-7axREG', '8-9axREG'],
#      'price': {'original': '15,99\xa0€',
#       'promotional': '4,80\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-70%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-70%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'PO224G08V-G11',
#    'name': 'T-shirt basique - nantucket red',
#    'price': {'original': '25,95\xa0€',
#     'promotional': '18,16\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['4a'],
#    'url_key': 'polo-ralph-lauren-t-shirt-basique-nantucket-red-po224g08v-g11',
#    'media': [{'path': 'PO/22/4G/08/VG/11/PO224G08V-G11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Polo Ralph Lauren',
#    'is_premium': True,
#    'family_articles': [{'sku': 'PO224G08V-G11',
#      'url_key': 'polo-ralph-lauren-t-shirt-basique-nantucket-red-po224g08v-g11',
#      'media': [{'path': 'PO/22/4G/08/VG/11/PO224G08V-G11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'T-shirt basique - nantucket red',
#      'sizes': ['4a'],
#      'price': {'original': '25,95\xa0€',
#       'promotional': '18,16\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-30%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'PO224G08V-H11',
#      'url_key': 'polo-ralph-lauren-t-shirt-basique-key-west-orange-po224g08v-h11',
#      'media': [{'path': 'PO/22/4G/08/VH/11/PO224G08V-H11@5.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'T-shirt basique - key west orange',
#      'sizes': ['M', 'L'],
#      'price': {'original': '32,95\xa0€',
#       'promotional': '19,77\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-40%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'PO224G08V-E11',
#      'url_key': 'polo-ralph-lauren-t-shirt-basique-yellow-fin-po224g08v-e11',
#      'media': [{'path': 'PO/22/4G/08/VE/11/PO224G08V-E11@5.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'T-shirt basique - yellow fin',
#      'sizes': ['M', 'L'],
#      'price': {'original': '32,95\xa0€',
#       'promotional': '32,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []},
#     {'sku': 'PO224G08V-H12',
#      'url_key': 'polo-ralph-lauren-t-shirt-basique-flare-orange-po224g08v-h12',
#      'media': [{'path': 'PO/22/4G/08/VH/12/PO224G08V-H12@7.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'T-shirt basique - flare orange',
#      'sizes': ['M'],
#      'price': {'original': '32,95\xa0€',
#       'promotional': '16,48\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-50%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'PO224G08V-M12',
#      'url_key': 'polo-ralph-lauren-t-shirt-basique-sunset-green-po224g08v-m12',
#      'media': [{'path': 'PO/22/4G/08/VM/12/PO224G08V-M12@6.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'T-shirt basique - sunset green',
#      'sizes': ['M', 'L'],
#      'price': {'original': '25,95\xa0€',
#       'promotional': '20,76\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'PO224G08V-M11',
#      'url_key': 'polo-ralph-lauren-t-shirt-basique-haven-green-po224g08v-m11',
#      'media': [{'path': 'PO/22/4G/08/VM/11/PO224G08V-M11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'T-shirt basique - haven green',
#      'sizes': ['M'],
#      'price': {'original': '27,95\xa0€',
#       'promotional': '27,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []},
#     {'sku': 'PO224G08V-K12',
#      'url_key': 'polo-ralph-lauren-t-shirt-basique-sapphire-star-po224g08v-k12',
#      'media': [{'path': 'PO/22/4G/08/VK/12/PO224G08V-K12@7.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'T-shirt basique - sapphire star',
#      'sizes': ['S', 'M', 'L'],
#      'price': {'original': '32,95\xa0€',
#       'promotional': '26,36\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}]},
#     {'sku': 'PO224G08V-J11',
#      'url_key': 'polo-ralph-lauren-t-shirt-basique-taylor-rose-po224g08v-j11',
#      'media': [{'path': 'PO/22/4G/08/VJ/11/PO224G08V-J11@5.jpg',
#        'role': 'FAMILY',
#        'packet_shot': False}],
#      'name': 'T-shirt basique - taylor rose',
#      'sizes': ['3a'],
#      'price': {'original': '25,95\xa0€',
#       'promotional': '25,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': []}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing'},
#   {'sku': 'JH183A02K-I11',
#    'name': 'LONG SLEEVES BABY - Body - damson',
#    'price': {'original': '19,95\xa0€',
#     'promotional': '10,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['9-12m'],
#    'url_key': 'joha-long-sleeves-baby-body-damson-jh183a02k-i11',
#    'media': [{'path': 'JH/18/3A/02/KI/11/JH183A02K-I11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Joha',
#    'is_premium': False,
#    'family_articles': [{'sku': 'JH183A02K-I11',
#      'url_key': 'joha-long-sleeves-baby-body-damson-jh183a02k-i11',
#      'media': [{'path': 'JH/18/3A/02/KI/11/JH183A02K-I11@8.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'LONG SLEEVES BABY - Body - damson',
#      'sizes': ['9-12m'],
#      'price': {'original': '19,95\xa0€',
#       'promotional': '10,00\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-50%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'underwear'},
#   {'sku': '4BE84B01Q-K11',
#    'name': 'BABY - Pyjama - light blue',
#    'price': {'original': '17,95\xa0€',
#     'promotional': '14,36\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['9-12m'],
#    'url_key': 'benetton-baby-pyjama-light-blue-4be84b01q-k11',
#    'media': [{'path': '4B/E8/4B/01/QK/11/4BE84B01Q-K11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Benetton',
#    'is_premium': False,
#    'family_articles': [{'sku': '4BE84B01Q-K11',
#      'url_key': 'benetton-baby-pyjama-light-blue-4be84b01q-k11',
#      'media': [{'path': '4B/E8/4B/01/QK/11/4BE84B01Q-K11@9.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'BABY - Pyjama - light blue',
#      'sizes': ['9-12m'],
#      'price': {'original': '17,95\xa0€',
#       'promotional': '14,36\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'campaign',
#        'value': '-15% EXTRA',
#        'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#       {'key': 'discountRate',
#        'value': '-20%',
#        'tracking_value': 'discount rate'}]}],
#    'flags': [{'key': 'campaign',
#      'value': '-15% EXTRA',
#      'tracking_value': 'fr_ss19_eoss_fs_wave_3_2019_26'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'nightwear'},
#   {'sku': 'STF26J003-C11',
#    'name': 'BABY - Gilet - mid grey melange',
#    'price': {'original': '17,95\xa0€',
#     'promotional': '17,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['4-6m'],
#    'url_key': 'staccato-baby-gilet-mid-grey-melange-stf26j003-c11',
#    'media': [{'path': 'ST/F2/6J/00/3C/11/STF26J003-C11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Staccato',
#    'is_premium': False,
#    'family_articles': [{'sku': 'STF26J003-C11',
#      'url_key': 'staccato-baby-gilet-mid-grey-melange-stf26j003-c11',
#      'media': [{'path': 'ST/F2/6J/00/3C/11/STF26J003-C11@2.jpg',
#        'role': 'FAMILY',
#        'packet_shot': True}],
#      'name': 'BABY - Gilet - mid grey melange',
#      'sizes': ['4-6m'],
#      'price': {'original': '17,95\xa0€',
#       'promotional': '17,95\xa0€',
#       'has_different_prices': False,
#       'has_different_original_prices': False,
#       'has_different_promotional_prices': False,
#       'has_discount_on_selected_sizes_only': False},
#      'flags': [{'key': 'csr',
#        'value': 'Éco-responsable',
#        'tracking_value': 'sustainable'}]}],
#    'flags': [{'key': 'csr',
#      'value': 'Éco-responsable',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing'}],
#  'query_path': '/promo-enfant/?p=242',
#  'previous_page_path': '/promo-enfant/?p=241',
#  'query_params': {'categories': 'promo-enfant',
#   'sort': 'sale',
#   'offset': '20244',
#   'limit': '84'},
#  'page_gender': 'kids',
#  'premium': False,
#  'filters': [{'key': 'sizes',
#    'label': 'Taille',
#    'url_key': 'size',
#    'kind': 'values',
#    'values': [{'key': '0-1m', 'label': '0-1m'},
#     {'key': '1-3m', 'label': '1-3m'},
#     {'key': '2a', 'label': '2a'},
#     {'key': '3a', 'label': '3a'},
#     {'key': '3-6m', 'label': '3-6m'},
#     {'key': '4a', 'label': '4a'},
#     {'key': '5a', 'label': '5a'},
#     {'key': '6a', 'label': '6a'},
#     {'key': '6-9m', 'label': '6-9m'},
#     {'key': '7a', 'label': '7a'},
#     {'key': '8a', 'label': '8a'},
#     {'key': '9a', 'label': '9a'},
#     {'key': '9-12m', 'label': '9-12m'},
#     {'key': '10a', 'label': '10a'},
#     {'key': '11a', 'label': '11a'},
#     {'key': '12m', 'label': '12m'},
#     {'key': '12a', 'label': '12a'},
#     {'key': '12-18m', 'label': '12-18m'},
#     {'key': '13a', 'label': '13a'},
#     {'key': '14a', 'label': '14a'},
#     {'key': '15a', 'label': '15a'},
#     {'key': '16a', 'label': '16a'},
#     {'key': '17', 'label': '17'},
#     {'key': '17a', 'label': '17a'},
#     {'key': '18', 'label': '18'},
#     {'key': '18m', 'label': '18m'},
#     {'key': '18a', 'label': '18a'},
#     {'key': '18.5', 'label': '18.5'},
#     {'key': '19', 'label': '19'},
#     {'key': '19.5', 'label': '19.5'},
#     {'key': '20', 'label': '20'},
#     {'key': '21', 'label': '21'},
#     {'key': '22', 'label': '22'},
#     {'key': '23', 'label': '23'},
#     {'key': '23.5', 'label': '23.5'},
#     {'key': '24', 'label': '24'},
#     {'key': '25', 'label': '25'},
#     {'key': '26', 'label': '26'},
#     {'key': '27', 'label': '27'},
#     {'key': '27.5', 'label': '27.5'},
#     {'key': '28', 'label': '28'},
#     {'key': '28.5', 'label': '28.5'},
#     {'key': '29', 'label': '29'},
#     {'key': '29.5', 'label': '29.5'},
#     {'key': '30', 'label': '30'},
#     {'key': '30.5', 'label': '30.5'},
#     {'key': '31', 'label': '31'},
#     {'key': '31.5', 'label': '31.5'},
#     {'key': '32', 'label': '32'},
#     {'key': '32.5', 'label': '32.5'},
#     {'key': '33', 'label': '33'},
#     {'key': '33.5', 'label': '33.5'},
#     {'key': '34', 'label': '34'},
#     {'key': '34.5', 'label': '34.5'},
#     {'key': '35', 'label': '35'},
#     {'key': '35.5', 'label': '35.5'},
#     {'key': '36', 'label': '36'},
#     {'key': '36.5', 'label': '36.5'},
#     {'key': '37', 'label': '37'},
#     {'key': '37.5', 'label': '37.5'},
#     {'key': '38', 'label': '38'},
#     {'key': '38.5', 'label': '38.5'},
#     {'key': '39', 'label': '39'},
#     {'key': '39.5', 'label': '39.5'},
#     {'key': '40', 'label': '40'},
#     {'key': '41', 'label': '41'},
#     {'key': '42', 'label': '42'},
#     {'key': '152', 'label': '152'},
#     {'key': '158', 'label': '158'},
#     {'key': '164', 'label': '164'},
#     {'key': '170', 'label': '170'},
#     {'key': '176', 'label': '176'},
#     {'key': 'One Size', 'label': 'One Size'},
#     {'key': 'S', 'label': 'S'},
#     {'key': 'M', 'label': 'M'},
#     {'key': 'L', 'label': 'L'},
#     {'key': 'XL', 'label': 'XL'}]},
#   {'key': 'brands',
#    'label': 'Marque',
#    'url_key': 'brand',
#    'kind': 'values',
#    'family_values': [{'key': 'A0F',
#      'label': 'Abercrombie & Fitch',
#      'is_family': False},
#     {'key': 'AB3', 'label': 'Absorba', 'is_family': False},
#     {'key': 'ADID', 'label': 'adidas', 'is_family': True},
#     {'key': 'TA4',
#      'label': 'adidas Golf',
#      'family_id': 'ADID',
#      'is_family': False},
#     {'key': 'AD1',
#      'label': 'adidas Originals',
#      'family_id': 'ADID',
#      'is_family': False},
#     {'key': 'AD5',
#      'label': 'adidas Performance',
#      'family_id': 'ADID',
#      'is_family': False},
#     {'key': 'AI2', 'label': 'Aigle', 'is_family': False},
#     {'key': 'ANT', 'label': 'Angel & Rocket', 'is_family': False},
#     {'key': 'A15', 'label': 'Arena', 'is_family': False},
#     {'key': 'A22', 'label': 'Armor lux', 'is_family': False},
#     {'key': 'AS1', 'label': 'ASICS', 'family_id': 'AS00', 'is_family': False},
#     {'key': 'BAK',
#      'label': 'Bardot Junior',
#      'family_id': 'BA01',
#      'is_family': False},
#     {'key': 'BE8', 'label': 'bellybutton', 'is_family': False},
#     {'key': 'BE9', 'label': 'Belstaff', 'is_family': False},
#     {'key': 'BE6', 'label': 'Bench', 'is_family': False},
#     {'key': '4BE', 'label': 'Benetton', 'is_family': False},
#     {'key': 'BIJ', 'label': 'BIDI BADU', 'is_family': False},
#     {'key': 'BI3',
#      'label': 'Bikkemberg Kids',
#      'family_id': 'BI02',
#      'is_family': False},
#     {'key': 'BI7', 'label': 'Billabong', 'is_family': False},
#     {'key': 'BH5', 'label': 'Billieblush', 'is_family': False},
#     {'key': 'BIA', 'label': 'Billybandit', 'is_family': False},
#     {'key': 'BI1',
#      'label': 'Birkenstock',
#      'family_id': 'BIRK',
#      'is_family': False},
#     {'key': 'B58', 'label': 'Bisgaard', 'is_family': False},
#     {'key': 'BJ2', 'label': 'Björn Borg', 'is_family': False},
#     {'key': 'BE0', 'label': 'Blue Effect', 'is_family': False},
#     {'key': 'BL8', 'label': 'Blue Seven', 'is_family': False},
#     {'key': 'BO9',
#      'label': 'BOSS Kidswear',
#      'family_id': 'BOSS',
#      'is_family': False},
#     {'key': 'B24', 'label': 'British Knights', 'is_family': False},
#     {'key': 'BU3',
#      'label': 'Buffalo',
#      'family_id': 'BU00',
#      'is_family': False},
#     {'key': 'CALV', 'label': 'Calvin Klein', 'is_family': True},
#     {'key': 'C18',
#      'label': 'Calvin Klein Jeans',
#      'family_id': 'CALV',
#      'is_family': False},
#     {'key': 'C17',
#      'label': 'Calvin Klein Swimwear',
#      'family_id': 'CALV',
#      'is_family': False},
#     {'key': 'C11',
#      'label': 'Calvin Klein Underwear',
#      'family_id': 'CALV',
#      'is_family': False},
#     {'key': 'C51', 'label': 'camano', 'is_family': False},
#     {'key': 'CA3', 'label': 'Camper', 'is_family': False},
#     {'key': 'C0V', 'label': 'Carrement Beau', 'is_family': False},
#     {'key': 'C74', 'label': 'Cars Jeans', 'is_family': False},
#     {'key': 'CJ2', 'label': "Carter's", 'is_family': False},
#     {'key': 'C27', 'label': 'Catimini', 'is_family': False},
#     {'key': 'CV3', 'label': 'CeLaVi', 'is_family': False},
#     {'key': 'C76',
#      'label': 'Champion',
#      'family_id': 'CH00',
#      'is_family': False},
#     {'key': 'CHT',
#      'label': 'Chi Chi Girls',
#      'family_id': 'CH01',
#      'is_family': False},
#     {'key': 'C38', 'label': 'Chiemsee', 'is_family': False},
#     {'key': 'CH3', 'label': 'Chipie', 'is_family': False},
#     {'key': 'CL8', 'label': 'Claesen‘s', 'is_family': False},
#     {'key': 'CLAR', 'label': 'Clarks', 'is_family': True},
#     {'key': 'CL1', 'label': 'Clarks', 'family_id': 'CLAR', 'is_family': False},
#     {'key': 'CX4', 'label': 'clic!', 'is_family': False},
#     {'key': 'C70', 'label': 'CMP', 'is_family': False},
#     {'key': '1CK', 'label': 'Color Kids', 'is_family': False},
#     {'key': 'CO6', 'label': 'Colors of California', 'is_family': False},
#     {'key': 'C23', 'label': 'Columbia', 'is_family': False},
#     {'key': 'CO4',
#      'label': 'Converse',
#      'family_id': 'CONV',
#      'is_family': False},
#     {'key': 'C1Q',
#      'label': 'Cotton On',
#      'family_id': 'CO04',
#      'is_family': False},
#     {'key': 'CR4', 'label': 'Crocs', 'is_family': False},
#     {'key': 'DX2', 'label': 'D-XEL', 'is_family': False},
#     {'key': 'DC1', 'label': 'DC Shoes', 'is_family': False},
#     {'key': 'DL7', 'label': 'Delicatelove', 'is_family': False},
#     {'key': 'DEN', 'label': 'Derhy Kids', 'is_family': False},
#     {'key': 'DE1', 'label': 'Desigual', 'is_family': False},
#     {'key': 'D47', 'label': 'Deuter', 'is_family': False},
#     {'key': 'D29',
#      'label': 'Diadora',
#      'family_id': 'DIAD',
#      'is_family': False},
#     {'key': 'DI5', 'label': 'Didriksons', 'is_family': False},
#     {'key': 'DI1', 'label': 'Diesel', 'family_id': 'DIES', 'is_family': False},
#     {'key': 'DM1', 'label': 'DIM', 'is_family': False},
#     {'key': 'DI2', 'label': 'Disney', 'family_id': 'DISN', 'is_family': False},
#     {'key': 'DIL',
#      'label': 'Disney Clarks',
#      'family_id': 'CLAR',
#      'is_family': False},
#     {'key': 'DK1', 'label': 'DKNY', 'family_id': 'DK00', 'is_family': False},
#     {'key': 'DO1', 'label': 'Dockers by Gerli', 'is_family': False},
#     {'key': 'DO2', 'label': 'Dr. Martens', 'is_family': False},
#     {'key': '4DR', 'label': 'Dreimaster', 'is_family': False},
#     {'key': 'D24', 'label': 'Döll', 'is_family': False},
#     {'key': 'EP1', 'label': 'Easy Peasy', 'is_family': False},
#     {'key': 'EB9', 'label': 'Ebbe', 'is_family': False},
#     {'key': 'EC1', 'label': 'ecco', 'is_family': False},
#     {'key': 'EE1', 'label': 'Elefanten', 'is_family': False},
#     {'key': 'EL8', 'label': 'Element', 'is_family': False},
#     {'key': 'EA8',
#      'label': 'Emporio Armani',
#      'family_id': 'ARMA',
#      'is_family': False},
#     {'key': 'EN6', 'label': 'Enter', 'is_family': False},
#     {'key': 'ES1', 'label': 'Esprit', 'family_id': 'ESPR', 'is_family': False},
#     {'key': 'EW3', 'label': 'Ewers', 'is_family': False},
#     {'key': 'FA0', 'label': 'Fabrizio', 'is_family': False},
#     {'key': 'FC4', 'label': 'Falcotto', 'is_family': False},
#     {'key': 'FA1', 'label': 'Falke', 'is_family': False},
#     {'key': 'FAO', 'label': 'Fat Face', 'is_family': False},
#     {'key': '1FI', 'label': 'Fila', 'family_id': 'FI00', 'is_family': False},
#     {'key': 'FIP', 'label': 'Finger in the nose', 'is_family': False},
#     {'key': 'FLC', 'label': 'Flik Flak', 'is_family': False},
#     {'key': 'FLE', 'label': 'Flower Mountain', 'is_family': False},
#     {'key': 'F0E',
#      'label': "Fred's World by GREEN COTTON",
#      'is_family': False},
#     {'key': 'F57', 'label': 'Friboo', 'is_family': False},
#     {'key': 'F01', 'label': 'Froddo', 'is_family': False},
#     {'key': 'F09', 'label': 'Frugi', 'is_family': False},
#     {'key': 'FU2', 'label': 'fullstop.', 'is_family': False},
#     {'key': 'GA3', 'label': 'GANT', 'family_id': 'GANT', 'is_family': False},
#     {'key': 'GP0', 'label': 'GAP', 'family_id': 'GA00', 'is_family': False},
#     {'key': 'GE1', 'label': 'Geox', 'is_family': False},
#     {'key': 'GI1', 'label': 'Giesswein', 'is_family': False},
#     {'key': 'G52', 'label': 'Gioseppo', 'is_family': False},
#     {'key': 'GRE', 'label': 'GRO', 'is_family': False},
#     {'key': 'GRF', 'label': 'Grunt', 'is_family': False},
#     {'key': 'GU1', 'label': 'Guess', 'is_family': False},
#     {'key': 'ASB',
#      'label': 'Hackett Aston Martin Racing',
#      'family_id': 'HA00',
#      'is_family': False},
#     {'key': 'HA00', 'label': 'Hackett London', 'is_family': True},
#     {'key': 'HT6',
#      'label': 'Hackett London',
#      'family_id': 'HA00',
#      'is_family': False},
#     {'key': 'HG2', 'label': 'happy girls', 'is_family': False},
#     {'key': 'HA1', 'label': 'Havaianas', 'is_family': False},
#     {'key': 'HAA', 'label': 'Hawkers', 'is_family': False},
#     {'key': 'HE7', 'label': 'Head', 'is_family': False},
#     {'key': 'HE6', 'label': 'Helly Hansen', 'is_family': False},
#     {'key': 'H15', 'label': 'Herschel', 'is_family': False},
#     {'key': 'HI2', 'label': 'Hi-Tec', 'is_family': False},
#     {'key': 'HI3', 'label': 'Hip', 'is_family': False},
#     {'key': 'HU3', 'label': 'Hummel', 'family_id': 'HU00', 'is_family': False},
#     {'key': 'HU1', 'label': 'Hunter', 'is_family': False},
#     {'key': 'HC3', 'label': 'Hust & Claire', 'is_family': False},
#     {'key': 'HY5', 'label': 'Hype', 'is_family': False},
#     {'key': 'IC1', 'label': 'Icepeak', 'is_family': False},
#     {'key': 'IG0', 'label': 'igi natur', 'is_family': False},
#     {'key': 'IP1', 'label': 'Ipanema', 'is_family': False},
#     {'key': 'JC4', 'label': 'J.CREW', 'family_id': 'JC00', 'is_family': False},
#     {'key': 'JAN',
#      'label': 'Jack & Jones Junior',
#      'family_id': 'JACK',
#      'is_family': False},
#     {'key': 'JA4', 'label': 'Jack Wolfskin', 'is_family': False},
#     {'key': 'J48', 'label': 'Jacky Baby', 'is_family': False},
#     {'key': 'JH1', 'label': 'Joha', 'is_family': False},
#     {'key': 'J26', 'label': 'JoJo Maman Bébé', 'is_family': False},
#     {'key': 'J33', 'label': 'Joma', 'is_family': False},
#     {'key': 'JOC', 'label': 'Jordan', 'is_family': False},
#     {'key': 'J35', 'label': 'Jottum', 'is_family': False},
#     {'key': 'KS1', 'label': 'K-SWISS', 'is_family': False},
#     {'key': 'KA6', 'label': 'Kamik', 'is_family': False},
#     {'key': 'KA1', 'label': 'KangaROOS', 'is_family': False},
#     {'key': 'K20', 'label': 'Kaporal', 'is_family': False},
#     {'key': '10K', 'label': 'Kappa', 'family_id': 'KAPP', 'is_family': False},
#     {'key': 'K48', 'label': 'KARL LAGERFELD', 'is_family': False},
#     {'key': 'K21', 'label': 'Kastinger', 'is_family': False},
#     {'key': 'KA4', 'label': 'Kavat', 'is_family': False},
#     {'key': 'KE5', 'label': 'Keen', 'is_family': False},
#     {'key': 'KE9', 'label': 'Kempa', 'is_family': False},
#     {'key': 'KG1',
#      'label': 'KG by Kurt Geiger',
#      'family_id': 'KU00',
#      'is_family': False},
#     {'key': 'KI1', 'label': 'Kickers', 'is_family': False},
#     {'key': 'KIJ',
#      'label': 'Kids ONLY',
#      'family_id': 'ON00',
#      'is_family': False},
#     {'key': 'K13', 'label': 'Killtec', 'is_family': False},
#     {'key': 'LAG', 'label': 'La Queue du Chat', 'is_family': False},
#     {'key': 'LACO', 'label': 'Lacoste', 'is_family': True},
#     {'key': 'LA2',
#      'label': 'Lacoste',
#      'family_id': 'LACO',
#      'is_family': False},
#     {'key': 'L06',
#      'label': 'Lacoste Sport',
#      'family_id': 'LACO',
#      'is_family': False},
#     {'key': 'LB3', 'label': 'Laura Biagiotti', 'is_family': False},
#     {'key': 'L45',
#      'label': 'LEGO Wear',
#      'family_id': 'LEGO',
#      'is_family': False},
#     {'key': 'LEG', 'label': 'Lemon Beret', 'is_family': False},
#     {'key': 'L14',
#      'label': 'Les Tropéziennes par M Belarbi',
#      'is_family': False},
#     {'key': 'LE2',
#      'label': "Levi's®",
#      'family_id': 'LEVI',
#      'is_family': False},
#     {'key': 'L52', 'label': 'LICO', 'is_family': False},
#     {'key': 'L1F', 'label': "Lil'Boo", 'is_family': False},
#     {'key': 'LIY', 'label': 'Lili Gaufrette', 'is_family': False},
#     {'key': 'LM5',
#      'label': 'Little Marc Jacobs',
#      'family_id': 'MAJA',
#      'is_family': False},
#     {'key': 'LI2', 'label': 'Living Kitzbühel', 'is_family': False},
#     {'key': 'L04', 'label': 'LMTD', 'is_family': False},
#     {'key': '1LO', 'label': 'Lotto', 'is_family': False},
#     {'key': 'LO7', 'label': 'Lowa', 'is_family': False},
#     {'key': 'LT1', 'label': 'LTB', 'is_family': False},
#     {'key': 'LU2', 'label': 'Lurchi', 'is_family': False},
#     {'key': 'L62', 'label': 'Lässig', 'is_family': False},
#     {'key': 'M14', 'label': 'Mads Nørgaard', 'is_family': False},
#     {'key': 'MAR', 'label': 'Mainio', 'is_family': False},
#     {'key': 'M91', 'label': 'Mango', 'family_id': 'MANG', 'is_family': False},
#     {'key': 'AX7', 'label': 'Maximo', 'is_family': False},
#     {'key': 'M3O', 'label': 'MAÁ', 'is_family': False},
#     {'key': 'MEQ', 'label': 'Melania', 'is_family': False},
#     {'key': 'ME1', 'label': 'Merrell', 'is_family': False},
#     {'key': 'MK1',
#      'label': 'MICHAEL Michael Kors',
#      'family_id': 'MICH',
#      'is_family': False},
#     {'key': 'MIH', 'label': 'mikk-line', 'is_family': False},
#     {'key': 'MI6', 'label': 'MINI A TURE', 'is_family': False},
# ...
#     {'key': 'VI2', 'label': 'Victoria Shoes', 'is_family': False},
#     {'key': 'VI1', 'label': 'Viking', 'is_family': False},
#     {'key': 'V20', 'label': 'Vingino', 'is_family': False},
#     {'key': 'BAS', 'label': 'wauw capow by bang bang', 'is_family': False},
#     {'key': 'WF5', 'label': 'WE Fashion', 'is_family': False},
#     {'key': 'WHA', 'label': 'Wheat', 'is_family': False},
#     {'key': 'WH9', 'label': 'White Stuff', 'is_family': False},
#     {'key': 'WO8', 'label': 'Woden', 'is_family': False},
#     {'key': 'XT1', 'label': 'XTI', 'is_family': False},
#     {'key': 'Y02', 'label': 'Young Versace', 'is_family': False},
#     {'key': 'Z21', 'label': 'Zadig & Voltaire', 'is_family': False},
#     {'key': 'ZAF',
#      'label': 'Zalando Essentials Kids',
#      'family_id': 'ZAES',
#      'is_family': False},
#     {'key': 'ZI7', 'label': 'Zip and Zoe', 'is_family': False},
#     {'key': 'IG2', 'label': ' IGOR ', 'is_family': False},
#     {'key': 'PO9', 'label': '3 Pommes', 'is_family': False}],
#    'family_key': 'brand_families'},
#   {'key': 'genders',
#    'label': 'Sexe',
#    'url_key': 'gender',
#    'kind': 'values',
#    'values': [{'key': 'FEMALE', 'label': 'Fille'},
#     {'key': 'MALE', 'label': 'Garçon'}]},
#   {'key': 'age_groups',
#    'label': 'Âge',
#    'url_key': 'gender',
#    'kind': 'values',
#    'values': [{'key': 'BABIES', 'label': 'Bébé'},
#     {'key': 'KIDS', 'label': 'Enfant'},
#     {'key': 'TEEN', 'label': 'Ado'}]},
#   {'key': 'prices',
#    'label': 'Prix',
#    'url_key': 'price',
#    'kind': 'range',
#    'range': {'min': 2.39,
#     'max': 396,
#     'unit': {'symbol': '€', 'position': 'suffix'}}},
#   {'key': 'colors',
#    'label': 'Couleur',
#    'url_key': 'color',
#    'kind': 'values',
#    'values': [{'key': 'BLACK', 'label': 'noir'},
#     {'key': 'BROWN', 'label': 'marron'},
#     {'key': 'BEIGE', 'label': 'beige'},
#     {'key': 'GRAY', 'label': 'gris'},
#     {'key': 'WHITE', 'label': 'blanc'},
#     {'key': 'BLUE', 'label': 'bleu'},
#     {'key': 'PETROL', 'label': 'bleu pétrole'},
#     {'key': 'TURQUOISE', 'label': 'turquoise'},
#     {'key': 'GREEN', 'label': 'vert'},
#     {'key': 'OLIVE', 'label': 'vert olive'},
#     {'key': 'YELLOW', 'label': 'jaune'},
#     {'key': 'ORANGE', 'label': 'orange'},
#     {'key': 'RED', 'label': 'rouge'},
#     {'key': 'PINK', 'label': 'rose'},
#     {'key': 'PURPLE', 'label': 'violet'},
#     {'key': 'GOLD', 'label': 'doré'},
#     {'key': 'SILVER', 'label': 'argenté'},
#     {'key': 'MULTICOLORED', 'label': 'multicolore'}]},
#   {'key': 'occasions',
#    'label': 'Occasion',
#    'url_key': 'occasion',
#    'kind': 'values',
#    'values': [{'key': 'LOUNGE_WEAR', 'label': 'confort/maison'},
#     {'key': 'OCTOBER_FEST', 'label': 'festival de la bière'},
#     {'key': 'EVENING', 'label': 'festive'},
#     {'key': 'BRIDAL', 'label': 'Looks de mariée'},
#     {'key': 'PARTY', 'label': 'soirée'},
#     {'key': 'LEISURE', 'label': 'sortie/détente'}]},
#   {'key': 'patterns',
#    'label': 'Motif',
#    'url_key': 'pattern',
#    'kind': 'values',
#    'values': [{'key': 'CAMOUFLAGE', 'label': 'camouflage'},
#     {'key': 'STRIPED', 'label': 'carreaux'},
#     {'key': 'HERRING_BONE', 'label': 'chevrons'},
#     {'key': 'FLECKED', 'label': 'chiné'},
#     {'key': 'PLAIN', 'label': 'couleur unie'},
#     {'key': 'GRADIENT', 'label': 'dégradé'},
#     {'key': 'BURNOUT', 'label': 'dévoré'},
#     {'key': 'PINSTRIPE', 'label': 'fines rayures'},
#     {'key': 'POLKA_DOT', 'label': 'floral'},
#     {'key': 'PRINT', 'label': 'imprimé'},
#     {'key': 'ANIMAL_PRINT', 'label': 'imprimé animal'},
#     {'key': 'PHOTO_PRINT', 'label': 'imprimé photo'},
#     {'key': 'COLORED', 'label': 'multicolore'},
#     {'key': 'PAISLEY', 'label': 'Paisley/cachemire'},
#     {'key': 'CHECKERED', 'label': 'rayures'},
#     {'key': 'FLORAL', 'label': 'à pois'}]},
#   {'key': 'sales',
#    'label': 'Soldes',
#    'url_key': 'sale',
#    'kind': 'single_value',
#    'values': [{'key': 'SALE', 'label': 'Voir les Promos'}]},
#   {'key': 'seasons',
#    'label': 'Saison',
#    'url_key': 'season_name',
#    'kind': 'values',
#    'values': [{'key': 'SUMMER', 'label': 'Printemps/Été'},
#     {'key': 'WINTER', 'label': 'Automne/Hiver'}]},
#   {'key': 'upper_materials',
#    'label': 'Matière',
#    'url_key': 'upper_material',
#    'kind': 'values',
#    'values': [{'key': 'OTHER', 'label': 'Autres matières'},
#     {'key': 'CASHMERE', 'label': 'Cachemire'},
#     {'key': 'CAOUTCHOUC', 'label': 'Caoutchouc'},
#     {'key': 'COTTON', 'label': 'Coton'},
#     {'key': 'CROCHETED', 'label': 'Crocheté'},
#     {'key': 'LEATHER', 'label': 'Cuir'},
#     {'key': 'CORD', 'label': 'Côtelé'},
#     {'key': 'DENIM', 'label': 'Denim'},
#     {'key': 'LACE', 'label': 'Dentelle'},
#     {'key': 'FELT', 'label': 'Feutre'},
#     {'key': 'HARDSHELL', 'label': 'Hardshell'},
#     {'key': 'IMITATION_LEATHER', 'label': 'Imitation cuir'},
#     {'key': 'JERSEY', 'label': 'Jersey'},
#     {'key': 'WOOL', 'label': 'Laine'},
#     {'key': 'LINEN', 'label': 'Lin'},
#     {'key': 'MESH', 'label': 'Mesh'},
#     {'key': 'MOHAIR', 'label': 'Mohair'},
#     {'key': 'FLEECE', 'label': 'Polaire'},
#     {'key': 'POLYESTER', 'label': 'Polyester'},
#     {'key': 'SATIN', 'label': 'Satin'},
#     {'key': 'SOFTSHELL', 'label': 'Softshell'},
#     {'key': 'SILK', 'label': 'Soie'},
#     {'key': 'RIB', 'label': 'Strié'},
#     {'key': 'SWEAT', 'label': 'Sweat'},
#     {'key': 'SYNTHETIC', 'label': 'Synthétique'},
#     {'key': 'TEXTILE', 'label': 'Textile'},
#     {'key': 'BRAIDED', 'label': 'tressé'},
#     {'key': 'VISCOSE', 'label': 'Viscose'}]},
#   {'key': 'trouser_rises',
#    'label': 'Type de taille',
#    'url_key': 'trouser_rise',
#    'kind': 'values',
#    'values': [{'key': 'LOW', 'label': 'basse'},
#     {'key': 'MEDIUM', 'label': 'normale'},
#     {'key': 'HIGH', 'label': 'haute'}]},
#   {'key': 'discounts',
#    'label': 'Réduction',
#    'url_key': 'discount',
#    'kind': 'values',
#    'values': [{'key': 'DISCOUNT0', 'label': 'jusqu’à -20 %'},
#     {'key': 'DISCOUNT1', 'label': '-20 %'},
#     {'key': 'DISCOUNT2', 'label': '-30 %'},
#     {'key': 'DISCOUNT3', 'label': '-40 %'},
#     {'key': 'DISCOUNT4', 'label': '-50 %'},
#     {'key': 'DISCOUNT5', 'label': '-60 % et plus'}]},
#   {'key': 'campaigns',
#    'label': 'Campaigns',
#    'url_key': 'camp',
#    'kind': 'single_value',
#    'values': [{'key': 'fr_ss19_eoss_fs_wave_3_2019_26', 'label': '-15% EXTRA'},
#     {'key': 'mu_sneaker_releases', 'label': 'Hot Sneaker Drops'}]},
#   {'key': 'fr_delivery_24h',
#    'label': 'Livraison 24H',
#    'url_key': 'livraison-24h',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Livraison 24H'}]},
#   {'key': 'sustainable',
#    'label': 'Éco-responsable',
#    'url_key': 'sustainable',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Éco-responsable'}]},
#   {'key': 'shipped_by_zalando',
#    'label': 'Expédié par Zalando',
#    'url_key': 'shipped_by_zalando',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Expédié par Zalando'}]}],
#  'total_article_count': 20259,
#  'plusStatus': 'unknown',
#  'categoryTree': [{'label': 'Promotions',
#    'id': '9574',
#    'url_key': 'promo-enfant',
#    'has_skus': True,
#    'selected': True,
#    'has_children': True,
#    'full_url': '/promo-enfant/',
#    'children': [{'label': 'Vêtements',
#      'id': '9579',
#      'url_key': 'promo-mode-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-mode-enfant/',
#      'children': [],
#      'article_count': 14812},
#     {'label': 'Chaussures',
#      'id': '9575',
#      'url_key': 'promo-chaussures-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-chaussures-enfant/',
#      'children': [],
#      'article_count': 4406},
#     {'label': 'Sport',
#      'id': '14007',
#      'url_key': 'promo-sport-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-sport-enfant/',
#      'children': [],
#      'article_count': 1959},
#     {'label': 'Sacs et accessoires',
#      'id': '9609',
#      'url_key': 'promo-accessoires-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-accessoires-enfant/',
#      'children': [],
#      'article_count': 767},
#     {'label': 'Luxe',
#      'id': '148690440',
#      'url_key': 'promo-luxe-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-luxe-enfant/',
#      'children': [],
#      'article_count': 2723}],
#    'article_count': 20256}],
#  'sortingKeys': [{'type': 'popularity', 'dir': 'desc', 'label': 'Préférés'},
#   {'type': 'activation_date', 'dir': 'desc', 'label': 'Nouveautés'},
#   {'type': 'price_asc', 'dir': 'asc', 'label': 'Prix croissant'},
#   {'type': 'price_desc', 'dir': 'desc', 'label': 'Prix décroissant'},
#   {'type': 'sale', 'dir': 'desc', 'label': 'Soldes'}],
#  'breadcrumbs': [{'items': [{'label': 'Enfant',
#      'url_key': 'enfant',
#      'full_url': '/enfant/'},
#     {'label': 'Promotions',
#      'url_key': 'promo-enfant',
#      'full_url': '/promo-enfant/'}]}],
#  'querySemantics': {'positive_filters': [{'key': 'categories',
#     'url_key': 'category',
#     'kind': 'values',
#     'values': [{'key': 'promo-enfant',
#       'url_key': 'promo-enfant',
#       'label': 'Promotions',
#       'seo_label': 'Promotions enfant',
#       'reset_url': '/',
#       'id': '9574'}]}],
#   'negative_filters': [],
#   'reset_query_url': '/promo-enfant/',
#   'reset_url': '/promo-enfant/',
#   'app_url': '?urlKey=promo-enfant&order=sale&appdomainId=11'},
#  'articlesToShow': 84,
#  'octopusTests': [],
#  'locale': 'fr-FR',
#  'isLoggedIn': False,
#  'notification': None,
#  'resetFilters': {'categories': [{'key': 'promo-enfant',
#     'url_key': 'promo-enfant',
#     'label': 'Promotions',
#     'seo_label': 'Promotions enfant',
#     'reset_url': '/',
#     'id': '9574'}]},
#  'selectedFilters': {'categories': ['promo-enfant']},
#  'ssrArticleCount': 32,
#  'feedbackId': '5c112594708a306b9e611805',
#  'variants': {'fullWidthCatalog': False,
#   'premiumCatalog': False,
#   'myBrandsFilter': True,
#   'outwardTeaserCard': False,
#   'hideCategories': False,
#   'mobileLightFilters': False},
#  'contentPositions': {'in-cat-carousel': 9,
#   'in-cat-carousel-mobile': 6,
#   'in-cat-carousel-fullwidth': 8,
#   'in-cat-teaser': 9,
#   'upper-in-cat-teaser': 5,
#   'entry-point-teasers': [7, 14, 20, 26],
#   'in-grid-filter': 4,
#   'size-dialog': 12,
#   'search-dialog': [9, 19],
#   'search-dialog-mobile': [8, 15],
#   'search-dialog-fullwidth': [12, 25],
#   'sneaker-carousel': [12],
#   'outfits': [5, 14, 23],
#   'outfits-mobile': [5, 11, 17, 23],
#   'outfits-fullwidth': [7, 19, 31, 43]},
#  'prideEnabled': True,
#  'seoText': None,
#  'teaser': {'content': {'creative_format': 'TEASER',
#    'brand': {'name': 'non-fashion brand', 'code': '-1'},
#    'pixels': ['https://creativefactory.zalando.fr/impressions/1f6fe085-10a8-4a90-9078-f18be79c3d0a/482f9f95-32a3-483b-b924-028f9d524a31/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=94b67aac-b45d-4712-ac56-463a402e7e74&timeUnit=null&timeUnitCount=null&uuid=994a5b75-faf1-469b-8f57-fc1ffe7767d3&bid=null&requestId=60954579-a0b6-417d-83f5-eff19e2d4313&s=546A9521BBB52FDFAE0446488B9A5D22'],
#    'images': [{'aspect_ratio': '75:64',
#      'max_screen_size': 600,
#      'image_url': 'https://mosaic03.ztat.net/crt/creative-content/94a9c57f-374d-404b-bcbe-5fa6c68e52cc.jpg',
#      'image_width': 750},
#     {'aspect_ratio': '16:3',
#      'max_screen_size': 1200,
#      'image_url': 'https://mosaic03.ztat.net/crt/creative-content/bd04d164-3e8f-4d0d-bdc1-1608735702ec.jpg',
#      'image_width': 3200}],
#    'creative_id': '94b67aac-b45d-4712-ac56-463a402e7e74',
#    'campaign_id': '1f6fe085-10a8-4a90-9078-f18be79c3d0a',
#    'campaign_name': 'TCT FR SS19 EOSS FS Wave 3 Kids_FR_FR_CHILD_July_15_16_CatAd_copy_C_000000',
#    'text_fields': {'cta': "J'en profite !",
#     'legal_claim': '*Offre valable du 15/07/2019 au 16/07/2019 jusqu\'à 23h59 sur les articles de la sélection "-15% EXTRA", pour un minimum d\'achat de 60€',
#     'voucher_code': 'SOLEIL19',
#     'sales_template': 'Voucher',
#     'title': 'Encore plus de styles',
#     'type': 'sales',
#     'byline': "SOLDES JUSQU'À -70% ET -15% EXTRA*",
#     'voucher_label': 'Code :'},
#    'tracking_events': {'impression': {'type': 'advertising-event',
#      'advertising-category': 'category',
#      'advertising-action': 'teaser impression',
#      'advertising-parameter': {'channel_name': 'CF',
#       'campaign_name': 'TCT FR SS19 EOSS FS Wave 3 Kids_FR_FR_CHILD_July_15_16_CatAd_copy_C_000000',
#       'brand_code': '-1',
#       'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#       'flow_id': 'sb6GpKSLO9OgdF-w',
#       'shop_slot_id': 'catalog',
#       'campaign_source_id': 'undefined',
#       'request_id': '60954579-a0b6-417d-83f5-eff19e2d4313',
#       'campaign_id': '1f6fe085-10a8-4a90-9078-f18be79c3d0a',
#       'creative_id': '94b67aac-b45d-4712-ac56-463a402e7e74'}},
#     'view': {'type': 'teaser view',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': '94b67aac-b45d-4712-ac56-463a402e7e74',
#      'name': 'Encore plus de styles',
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'TCT FR SS19 EOSS FS Wave 3 Kids_FR_FR_CHILD_July_15_16_CatAd_copy_C_000000',
#        'brand_code': '-1',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': 'sb6GpKSLO9OgdF-w',
#        'shop_slot_id': 'catalog',
#        'campaign_source_id': 'undefined',
#        'request_id': '60954579-a0b6-417d-83f5-eff19e2d4313',
#        'campaign_id': '1f6fe085-10a8-4a90-9078-f18be79c3d0a',
#        'creative_id': '94b67aac-b45d-4712-ac56-463a402e7e74'}}},
#     'click': {'type': 'teaser click',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': '94b67aac-b45d-4712-ac56-463a402e7e74',
#      'name': 'Encore plus de styles',
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'TCT FR SS19 EOSS FS Wave 3 Kids_FR_FR_CHILD_July_15_16_CatAd_copy_C_000000',
#        'brand_code': '-1',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': 'sb6GpKSLO9OgdF-w',
#        'shop_slot_id': 'catalog',
#        'campaign_source_id': 'undefined',
#        'request_id': '60954579-a0b6-417d-83f5-eff19e2d4313',
#        'campaign_id': '1f6fe085-10a8-4a90-9078-f18be79c3d0a',
#        'creative_id': '94b67aac-b45d-4712-ac56-463a402e7e74'}}}},
#    'view_pixels': ['https://creativefactory.zalando.fr/views/1f6fe085-10a8-4a90-9078-f18be79c3d0a/482f9f95-32a3-483b-b924-028f9d524a31/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=94b67aac-b45d-4712-ac56-463a402e7e74&timeUnit=null&timeUnitCount=null&uuid=5ef03af4-7db4-40de-a54a-7dda184fcf90&bid=null&requestId=60954579-a0b6-417d-83f5-eff19e2d4313&s=B2D11769F5A9E1CA0441E82B141C6E0A'],
#    'tracking_data': {'explicit_tracking_params': {'flow_id': 'sb6GpKSLO9OgdF-w',
#      'entity_id': None,
#      'shop_slot_id': 'catalog',
#      'brand_code': '-1',
#      'campaign_source_id': None,
#      'campaign_id': '1f6fe085-10a8-4a90-9078-f18be79c3d0a',
#      'creative_id': '94b67aac-b45d-4712-ac56-463a402e7e74',
#      'campaign_name': 'TCT FR SS19 EOSS FS Wave 3 Kids_FR_FR_CHILD_July_15_16_CatAd_copy_C_000000',
#      'target_entity_id': None},
#     'cf_tracking_params': {'channel_name': 'CF',
#      'campaign_name': 'TCT FR SS19 EOSS FS Wave 3 Kids_FR_FR_CHILD_July_15_16_CatAd_copy_C_000000',
#      'brand_code': '-1',
#      'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#      'flow_id': 'sb6GpKSLO9OgdF-w',
#      'shop_slot_id': 'catalog',
#      'campaign_source_id': 'undefined',
#      'request_id': '60954579-a0b6-417d-83f5-eff19e2d4313',
#      'campaign_id': '1f6fe085-10a8-4a90-9078-f18be79c3d0a',
#      'creative_id': '94b67aac-b45d-4712-ac56-463a402e7e74'}},
#    'click_url': 'https://www.zalando.fr/enfant/?camp=fr_ss19_eoss_fs_wave_3_2019_26'},
#   'channel_name': 'CF',
#   'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a'},
#  'inCatalogTeaser': None,
#  'entryPointTeasers': None,
#  'upperInCatTeaser': None,
#  'collection': None,
#  'carouselTeaser': None,
#  'wishlist': None,
#  'pills': None,
#  'styleYourKicks': None,
#  'sizeOnboardingDialog': None}

# %%
# Your code
header = {'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36'}


response = requests.get(url, headers = header)
results = response.json()
results


flattened_data = json_normalize(results)

flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
#    amount           brand_name  \
# 0     NaN              Name it
# 1     NaN                  GAP
# 2     NaN           Pepe Jeans
# 3     NaN           Quiksilver
# 4     NaN             Benetton
# 5     NaN             Benetton
# 6     NaN             Staccato
# 7     NaN             Benetton
# 8     NaN             Staccato
# 9     NaN             Benetton
# 10    NaN             Benetton
# 11    NaN     Nike Performance
# 12    NaN              Lacoste
# 13    NaN      Nike Sportswear
# 14    NaN     Nike Performance
# 15    NaN               Esprit
# 16    NaN            Sunnylife
# 17    NaN             Benetton
# 18    NaN         River Island
# 19    NaN     Nike Performance
# 20    NaN          Blue Effect
# 21    NaN               Re-Gen
# 22    NaN                 LMTD
# 23    NaN     Nike Performance
# 24    NaN         River Island
# 25    NaN             3 Pommes
# 26    NaN                  OVS
# 27    NaN   adidas Performance
# 28    NaN             Benetton
# 29    NaN           Pepe Jeans
# ..    ...                  ...
# 54  122 g     Nike Performance
# 55    NaN      Nike Sportswear
# 56    NaN               Friboo
# 57    NaN    Polo Ralph Lauren
# 58    NaN              Lacoste
# 59    NaN               Friboo
# 60    NaN     adidas Originals
# 61    NaN     Nike Performance
# 62    NaN               Friboo
# 63    NaN             Benetton
# 64    NaN             Benetton
# 65    NaN              Name it
# 66    NaN             Converse
# 67    NaN                  OVS
# 68    NaN  Abercrombie & Fitch
# 69    NaN           Pepe Jeans
# 70    NaN             Champion
# 71    NaN         Retour Jeans
# 72    NaN           TOM TAILOR
# 73    NaN           Mini Molly
# 74    NaN               Esprit
# 75    NaN                 LMTD
# 76    NaN               Esprit
# 77    NaN  Abercrombie & Fitch
# 78    NaN           Blue Seven
# 79    NaN                 LMTD
# 80    NaN     Nike Performance
# 81    NaN              Nike SB
# 82    NaN                  GAP
# 83    NaN          Outfit Kids
#
#                                       family_articles  \
# 0   [{'sku': 'NA823F0VH-K11', 'url_key': 'name-it-...
# 1   [{'sku': 'GP024G0FG-E11', 'url_key': 'gap-marc...
# 2   [{'sku': 'PE123J028-C11', 'url_key': 'pepe-jea...
# 3   [{'sku': 'QU124L01V-K11', 'url_key': 'quiksilv...
# 4   [{'sku': '4BE23F082-A11', 'url_key': 'benetton...
# 5   [{'sku': '4BE24I023-K15', 'url_key': 'benetton...
# 6   [{'sku': 'STF24C00P-T11', 'url_key': 'staccato...
# 7   [{'sku': '4BE23F083-I11', 'url_key': 'benetton...
# 8   [{'sku': 'STF23K018-C11', 'url_key': 'staccato...
# 9   [{'sku': '4BE23G0DU-K11', 'url_key': 'benetton...
# 10  [{'sku': '4BE23G0DU-A11', 'url_key': 'benetton...
# 11  [{'sku': 'N1243G09Y-G11', 'url_key': 'nike-per...
# 12  [{'sku': 'LA253M003-K11', 'url_key': 'lacoste-...
# 13  [{'sku': 'NI114D0A9-C11', 'url_key': 'nike-spo...
# 14  [{'sku': 'N1243K0B0-Q11', 'url_key': 'nike-per...
# 15  [{'sku': 'ES123A099-G11', 'url_key': 'esprit-p...
# 16  [{'sku': 'SUF53I000-E11', 'url_key': 'sunnylif...
# 17  [{'sku': '4BE24A05P-H11', 'url_key': 'benetton...
# 18  [{'sku': 'RI923G01Y-A11', 'url_key': 'river-is...
# 19  [{'sku': 'N1243G09X-Q11', 'url_key': 'nike-per...
# 20  [{'sku': 'BE024B00K-K11', 'url_key': 'blue-eff...
# 21  [{'sku': 'RG524K00Q-C11', 'url_key': 're-gen-t...
# 22  [{'sku': 'L0423J00N-B11', 'url_key': 'lmtd-nlf...
# 23  [{'sku': 'N1243E0KJ-K12', 'url_key': 'nike-per...
# 24  [{'sku': 'RI923D02C-A11', 'url_key': 'river-is...
# 25  [{'sku': 'PO923F02X-A12', 'url_key': '3-pommes...
# 26  [{'sku': 'OV024G0AC-C11', 'url_key': 'ovs-stri...
# 27  [{'sku': 'AD543G08G-C11', 'url_key': 'adidas-p...
# 28  [{'sku': '4BE23L04D-K11', 'url_key': 'benetton...
# 29  [{'sku': 'PE113D00C-A11', 'url_key': 'pepe-jea...
# ..                                                ...
# 54  [{'sku': 'N1243A0PN-C13', 'url_key': 'nike-per...
# 55  [{'sku': 'NI114D04L-Q11', 'url_key': 'nike-spo...
# 56  [{'sku': 'F5723K022-E11', 'url_key': 'friboo-s...
# 57  [{'sku': 'PO224D033-A11', 'url_key': 'polo-ral...
# 58  [{'sku': 'LA224K00X-K11', 'url_key': 'lacoste-...
# 59  [{'sku': 'F5723G04A-I11', 'url_key': 'friboo-g...
# 60  [{'sku': 'AD116D0JK-J11', 'url_key': 'adidas-o...
# 61  [{'sku': 'N1243D11U-Q11', 'url_key': 'nike-per...
# 62  [{'sku': 'F5723K024-I11', 'url_key': 'friboo-n...
# 63  [{'sku': '4BE24B03K-N11', 'url_key': 'benetton...
# 64  [{'sku': '4BE24G0CE-K11', 'url_key': 'benetton...
# 65  [{'sku': 'NA823L0BT-K11', 'url_key': 'name-it-...
# 66  [{'sku': 'CO413A01B-A11', 'url_key': 'converse...
# 67  [{'sku': 'OV023F03F-G11', 'url_key': 'ovs-stri...
# 68  [{'sku': 'A0F23G039-K11', 'url_key': 'abercrom...
# 69  [{'sku': 'PE124L03A-K11', 'url_key': 'pepe-jea...
# 70  [{'sku': 'C7643G02Q-H11', 'url_key': 'champion...
# 71  [{'sku': 'RJ223A01E-K11', 'url_key': 'retour-j...
# 72  [{'sku': 'TO223G0F5-J11', 'url_key': 'tom-tail...
# 73  [{'sku': 'MM723C006-K11', 'url_key': 'mini-mol...
# 74  [{'sku': 'ES124G0HK-A11', 'url_key': 'esprit-t...
# 75  [{'sku': 'NA823K0E0-C11', 'url_key': 'name-it-...
# 76  [{'sku': 'ES124G0IA-M11', 'url_key': 'esprit-t...
# 77  [{'sku': 'A0F23K00Z-G11', 'url_key': 'abercrom...
# 78  [{'sku': 'BL823F070-J11', 'url_key': 'blue-sev...
# 79  [{'sku': 'L0424K00Y-K11', 'url_key': 'lmtd-nlm...
# 80  [{'sku': 'N1243G022-C11', 'url_key': 'nike-per...
# 81  [{'sku': 'NS414D005-K23', 'url_key': 'nike-sb-...
# 82  [{'sku': 'GP024G0EZ-C11', 'url_key': 'gap-boys...
# 83  [{'sku': 'OU524G03D-E11', 'url_key': 'outfit-k...
#
#                                                 flags  is_premium  \
# 0   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 1   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 2   [{'key': 'discountRate', 'value': 'Jusqu’à -70...       False
# 3   [{'key': 'discountRate', 'value': '-50%', 'tra...       False
# 4   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 5   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 6   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 7   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 8   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 9   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 10  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 12  [{'key': 'campaign', 'value': '-15% EXTRA', 't...        True
# 13  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 14  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 15  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 16  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 17  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 18  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 19  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 20  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 21  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 22  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 23  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 24  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 25  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 26  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 27  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 28  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 29  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# ..                                                ...         ...
# 54  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 55  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 56  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 57  [{'key': 'campaign', 'value': '-15% EXTRA', 't...        True
# 58  [{'key': 'campaign', 'value': '-15% EXTRA', 't...        True
# 59  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 60  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 61  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 62  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 63  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 64  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 65  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 66  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 67  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 68  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 69  [{'key': 'discountRate', 'value': 'Jusqu’à -70...       False
# 70  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 71  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 72  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 73  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 74  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 75  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 76  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 77  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 78  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 79  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 80  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 81  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 82  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 83  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
#
#                                                 media  \
# 0   [{'path': 'NA/82/3F/0V/HK/11/NA823F0VH-K11@2.j...
# 1   [{'path': 'GP/02/4G/0F/GE/11/GP024G0FG-E11@7.j...
# 2   [{'path': 'PE/12/3J/02/8C/11/PE123J028-C11@4.j...
# 3   [{'path': 'QU/12/4L/01/VK/11/QU124L01V-K11@11....
# 4   [{'path': '4B/E2/3F/08/2A/11/4BE23F082-A11@2.j...
# 5   [{'path': '4B/E2/4I/02/3K/15/4BE24I023-K15@2.j...
# 6   [{'path': 'ST/F2/4C/00/PT/11/STF24C00P-T11@11....
# 7   [{'path': '4B/E2/3F/08/3I/11/4BE23F083-I11@2.j...
# 8   [{'path': 'ST/F2/3K/01/8C/11/STF23K018-C11@2.j...
# 9   [{'path': '4B/E2/3G/0D/UK/11/4BE23G0DU-K11@4.j...
# 10  [{'path': '4B/E2/3G/0D/UA/11/4BE23G0DU-A11@2.j...
# 11  [{'path': 'N1/24/3G/09/YG/11/N1243G09Y-G11@8.j...
# 12  [{'path': 'LA/25/3M/00/3K/11/LA253M003-K11@5.j...
# 13  [{'path': 'NI/11/4D/0A/9C/11/NI114D0A9-C11@3.j...
# 14  [{'path': 'N1/24/3K/0B/0Q/11/N1243K0B0-Q11@6.j...
# 15  [{'path': 'ES/12/3A/09/9G/11/ES123A099-G11@5.j...
# 16  [{'path': 'SU/F5/3I/00/0E/11/SUF53I000-E11@3.j...
# 17  [{'path': '4B/E2/4A/05/PH/11/4BE24A05P-H11@8.j...
# 18  [{'path': 'RI/92/3G/01/YA/11/RI923G01Y-A11@5.j...
# 19  [{'path': 'N1/24/3G/09/XQ/11/N1243G09X-Q11@4.j...
# 20  [{'path': 'BE/02/4B/00/KK/11/BE024B00K-K11@2.j...
# 21  [{'path': 'RG/52/4K/00/QC/11/RG524K00Q-C11@8.j...
# 22  [{'path': 'L0/42/3J/00/NB/11/L0423J00N-B11@9.j...
# 23  [{'path': 'N1/24/3E/0K/JK/12/N1243E0KJ-K12@7.j...
# 24  [{'path': 'RI/92/3D/02/CA/11/RI923D02C-A11@7.j...
# 25  [{'path': 'PO/92/3F/02/XA/12/PO923F02X-A12@7.j...
# 26  [{'path': 'OV/02/4G/0A/CC/11/OV024G0AC-C11@2.j...
# 27  [{'path': 'AD/54/3G/08/GC/11/AD543G08G-C11@8.j...
# 28  [{'path': '4B/E2/3L/04/DK/11/4BE23L04D-K11@4.j...
# 29  [{'path': 'PE/11/3D/00/CA/11/PE113D00C-A11@8.j...
# ..                                                ...
# 54  [{'path': 'N1/24/3A/0P/NC/13/N1243A0PN-C13@10....
# 55  [{'path': 'NI/11/4D/04/LQ/11/NI114D04L-Q11@11....
# 56  [{'path': 'F5/72/3K/02/2E/11/F5723K022-E11@4.j...
# 57  [{'path': 'PO/22/4D/03/3A/11/PO224D033-A11@9.j...
# 58  [{'path': 'LA/22/4K/00/XK/11/LA224K00X-K11@12....
# 59  [{'path': 'F5/72/3G/04/AI/11/F5723G04A-I11@11....
# 60  [{'path': 'AD/11/6D/0J/KJ/11/AD116D0JK-J11@3.j...
# 61  [{'path': 'N1/24/3D/11/UQ/11/N1243D11U-Q11@12....
# 62  [{'path': 'F5/72/3K/02/4I/11/F5723K024-I11@11....
# 63  [{'path': '4B/E2/4B/03/KN/11/4BE24B03K-N11@2.j...
# 64  [{'path': '4B/E2/4G/0C/EK/11/4BE24G0CE-K11@12....
# 65  [{'path': 'NA/82/3L/0B/TK/11/NA823L0BT-K11@10....
# 66  [{'path': 'CO/41/3A/01/BA/11/CO413A01B-A11@12....
# 67  [{'path': 'OV/02/3F/03/FG/11/OV023F03F-G11@2.1...
# 68  [{'path': 'A0/F2/3G/03/9K/11/A0F23G039-K11@2.j...
# 69  [{'path': 'PE/12/4L/03/AK/11/PE124L03A-K11@8.j...
# 70  [{'path': 'C7/64/3G/02/QH/11/C7643G02Q-H11@10....
# 71  [{'path': 'RJ/22/3A/01/EK/11/RJ223A01E-K11@4.j...
# 72  [{'path': 'TO/22/3G/0F/5J/11/TO223G0F5-J11@6.j...
# 73  [{'path': 'MM/72/3C/00/6K/11/MM723C006-K11@7.j...
# 74  [{'path': 'ES/12/4G/0H/KA/11/ES124G0HK-A11@12....
# 75  [{'path': 'NA/82/3K/0E/0C/11/NA823K0E0-C11@6.1...
# 76  [{'path': 'ES/12/4G/0I/AM/11/ES124G0IA-M11@10....
# 77  [{'path': 'A0/F2/3K/00/ZG/11/A0F23K00Z-G11@6.j...
# 78  [{'path': 'BL/82/3F/07/0J/11/BL823F070-J11@11....
# 79  [{'path': 'L0/42/4K/00/YK/11/L0424K00Y-K11@2.j...
# 80  [{'path': 'N1/24/3G/02/2C/11/N1243G022-C11@8.j...
# 81  [{'path': 'NS/41/4D/00/5K/23/NS414D005-K23@3.j...
# 82  [{'path': 'GP/02/4G/0E/ZC/11/GP024G0EZ-C11@4.j...
# 83  [{'path': 'OU/52/4G/03/DE/11/OU524G03D-E11@5.j...
#
#                                                  name  \
# 0     DRESS CAMPMINI - Robe en jersey - dark sapphire
# 1                     T-shirt imprimé - canary yellow
# 2                       PATSIE - Pullover - grey marl
# 3                                Veste d'hiver - navy
# 4                DRESS - Robe en jersey - white/black
# 5                                      Chemise - blue
# 6   BERMUDAS 2 PACK - Short - indigo structure/sun...
# 7                      DRESS - Robe en jersey - lilac
# 8             HOODIE - Sweat à capuche - grey melange
# 9                            BASIC - Polo - dark blue
# 10                               BASIC - Polo - white
# 11  HOODIE - veste en sweat zippée - university re...
# 12                         BOY  - Chapeau - navy blue
# 13  MD RUNNER 2 - Baskets basses - atmosphere grey...
# 14  AIR MAX BODYSUIT BOOTIE SET - Survêtement - black
# 15                     PANTS - Jean slim - watermelon
# 16       GIRAFFE KIDS LUNCH BAG - Sac à main - yellow
# 17             TROUSERS BASIC - Jean slim - dark blue
# 18                                     Blouse - white
# 19  veste en sweat zippée - black/sail/university ...
# 20         BOYS - Pantalon de survêtement - nachtblau
# 21                   TEENS  - Pullover - grey melange
# 22           NLFDAMIER O NECK - Sweatshirt - moonbeam
# 23  DRY ACADEMY PANT - Pantalon de survêtement - i...
# 24                      veste en sweat zippée - white
# 25          DRESS MANCHES - Robe d'été - broken white
# 26                             STRIPES - Polo - righe
# 27   Sweat à capuche - medium grey heather/shock cyan
# 28           JACKET BASIC - Veste d'hiver - dark blue
# 29              BELLE HEARTH - Baskets basses - white
# ..                                                ...
# 54  REVOLUTION 4 - Chaussures de running neutres -...
# 55                AIR MAX 90 - Baskets basses - black
# 56                        Sweatshirt - mineral yellow
# 57  STRIPE ONE PIECE - Combinaison - white/french ...
# 58  BOY  - Sweat à capuche - salvia/navy blue/silv...
# 59      GO FOR IT  - T-shirt imprimé - orchid bouquet
# 60  CAMPUS - Baskets basses - light pink/footwear ...
# 61                DRY - T-shirt imprimé - black/white
# 62  NO RULES CROP HOODY - Sweat à capuche - purple...
# 63                     TROUSERS BASIC - Chino - khaki
# 64                             T-shirt imprimé - blue
# 65  NMFMELLO JACKET UNICORNSMINI - Veste mi-saison...
# 66  CHUCK TAYLOR FIRST STAR - Chaussons pour bébé ...
# 67  STRIPED DRESS GIRL - Robe en jersey - chinese red
# 68                        GRAPHIC - Sweatshirt - navy
# 69             BRANDON - Veste mi-saison - steel blue
# 70  AMERICAN CLASSICS HOODED  - Sweat à capuche - ...
# 71                  ZITA - Jeans Skinny - medium blue
# 72  PLACED PRINT - T-shirt à manches longues - sil...
# 73                     STAR GIRLS - Short - navy blue
# 74                            T-shirt imprimé - white
# 75                           Sweatshirt - sky captain
# 76                       T-shirt imprimé - soft green
# 77          COLORBLOCK CREW - Sweatshirt - light pink
# 78                            Robe en jersey - azalee
# 79                 NLMRAMI - Sweatshirt - sky captain
# 80            Sweat à capuche - dk grey heather/white
# 81  STEFAN JANOSKI - Baskets basses - obsidian/lig...
# 82  BOYS HENLEY - T-shirt imprimé - light grey hea...
# 83  THIS KIDS GOT SKILLS TEE - T-shirt imprimé - y...
#
#     price.has_different_original_prices  price.has_different_prices  \
# 0                                 False                       False
# 1                                 False                       False
# 2                                 False                        True
# 3                                 False                       False
# 4                                 False                       False
# 5                                 False                       False
# 6                                 False                       False
# 7                                 False                       False
# 8                                 False                       False
# 9                                 False                       False
# 10                                False                       False
# 11                                False                        True
# 12                                False                        True
# 13                                False                        True
# 14                                False                       False
# 15                                False                        True
# 16                                False                       False
# 17                                False                       False
# 18                                False                       False
# 19                                False                        True
# 20                                False                       False
# 21                                False                       False
# 22                                False                        True
# 23                                False                        True
# 24                                False                       False
# 25                                False                       False
# 26                                False                       False
# 27                                False                       False
# 28                                False                       False
# 29                                False                        True
# ..                                  ...                         ...
# 54                                False                       False
# 55                                False                        True
# 56                                False                        True
# 57                                False                       False
# 58                                False                        True
# 59                                False                        True
# 60                                False                        True
# 61                                False                        True
# 62                                False                        True
# 63                                False                       False
# 64                                False                       False
# 65                                False                       False
# 66                                False                       False
# 67                                False                       False
# 68                                False                       False
# 69                                False                        True
# 70                                False                       False
# 71                                False                       False
# 72                                False                       False
# 73                                False                       False
# 74                                False                       False
# 75                                False                       False
# 76                                False                       False
# 77                                False                       False
# 78                                False                       False
# 79                                False                       False
# 80                                False                       False
# 81                                False                       False
# 82                                False                       False
# 83                                False                       False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                    False
# 2                                     True
# 3                                    False
# 4                                    False
# 5                                    False
# 6                                    False
# 7                                    False
# 8                                    False
# 9                                    False
# 10                                   False
# 11                                    True
# 12                                    True
# 13                                    True
# 14                                   False
# 15                                    True
# 16                                   False
# 17                                   False
# 18                                   False
# 19                                    True
# 20                                   False
# 21                                   False
# 22                                    True
# 23                                    True
# 24                                   False
# 25                                   False
# 26                                   False
# 27                                   False
# 28                                   False
# 29                                    True
# ..                                     ...
# 54                                   False
# 55                                    True
# 56                                    True
# 57                                   False
# 58                                    True
# 59                                    True
# 60                                    True
# 61                                    True
# 62                                    True
# 63                                   False
# 64                                   False
# 65                                   False
# 66                                   False
# 67                                   False
# 68                                   False
# 69                                    True
# 70                                   False
# 71                                   False
# 72                                   False
# 73                                   False
# 74                                   False
# 75                                   False
# 76                                   False
# 77                                   False
# 78                                   False
# 79                                   False
# 80                                   False
# 81                                   False
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only price.original  \
# 0                                       False        12,95 €
# 1                                       False        12,95 €
# 2                                       False        59,95 €
# 3                                       False        75,99 €
# 4                                       False        19,95 €
# 5                                       False        19,95 €
# 6                                       False        17,95 €
# 7                                       False        19,95 €
# 8                                       False        29,95 €
# 9                                       False        17,95 €
# 10                                      False        17,95 €
# 11                                      False        54,95 €
# 12                                      False        40,00 €
# 13                                      False        44,95 €
# 14                                      False        19,95 €
# 15                                      False        25,95 €
# 16                                      False        24,95 €
# 17                                      False        25,95 €
# 18                                      False        26,00 €
# 19                                      False        54,95 €
# 20                                      False        39,99 €
# 21                                      False        29,95 €
# 22                                      False        28,95 €
# 23                                      False        39,95 €
# 24                                      False        36,00 €
# 25                                      False        49,95 €
# 26                                      False        12,95 €
# 27                                      False        37,95 €
# 28                                      False        39,95 €
# 29                                      False        54,95 €
# ..                                        ...            ...
# 54                                      False        29,95 €
# 55                                      False        74,95 €
# 56                                      False        17,95 €
# 57                                      False        45,95 €
# 58                                      False        72,00 €
# 59                                      False        14,95 €
# 60                                      False        64,95 €
# 61                                      False        24,95 €
# 62                                      False        19,95 €
# 63                                      False        22,95 €
# 64                                      False         9,95 €
# 65                                      False        24,99 €
# 66                                      False        29,95 €
# 67                                      False        15,95 €
# 68                                      False        28,95 €
# 69                                      False        84,95 €
# 70                                      False        27,95 €
# 71                                      False        54,95 €
# 72                                      False        15,99 €
# 73                                      False        34,95 €
# 74                                      False        12,99 €
# 75                                      False        32,99 €
# 76                                      False        15,95 €
# 77                                      False        37,95 €
# 78                                      False        12,95 €
# 79                                      False        36,95 €
# 80                                      False        34,95 €
# 81                                      False        59,95 €
# 82                                      False        19,95 €
# 83                                      False        12,95 €
#
#    price.promotional product_group  \
# 0             3,89 €      clothing
# 1             3,89 €      clothing
# 2            17,95 €      clothing
# 3            38,00 €      clothing
# 4             6,00 €      clothing
# 5             9,00 €      clothing
# 6             5,40 €      clothing
# 7             6,00 €      clothing
# 8             9,00 €      clothing
# 9             7,18 €      clothing
# 10            7,18 €      clothing
# 11           44,00 €      clothing
# 12           28,00 €   accessoires
# 13           31,46 €          shoe
# 14           12,95 €      clothing
# 15            7,80 €      clothing
# 16            7,50 €   accessoires
# 17           10,38 €      clothing
# 18           10,40 €      clothing
# 19           29,95 €      clothing
# 20           12,00 €      clothing
# 21            9,00 €      clothing
# 22            8,70 €      clothing
# 23           14,00 €      clothing
# 24           18,00 €      clothing
# 25           14,95 €      clothing
# 26            4,53 €      clothing
# 27           15,00 €      clothing
# 28           23,95 €      clothing
# 29           27,48 €          shoe
# ..               ...           ...
# 54           21,00 €          shoe
# 55           52,46 €          shoe
# 56            9,87 €      clothing
# 57           25,45 €      clothing
# 58           50,00 €      clothing
# 59            4,49 €      clothing
# 60           32,48 €          shoe
# 61           19,95 €      clothing
# 62           10,00 €      clothing
# 63           10,35 €      clothing
# 64            3,00 €      clothing
# 65           12,49 €      clothing
# 66           19,47 €          shoe
# 67            6,38 €      clothing
# 68            8,70 €      clothing
# 69           25,45 €      clothing
# 70           22,35 €      clothing
# 71           16,45 €      clothing
# 72            4,80 €      clothing
# 73           17,48 €      clothing
# 74            3,90 €      clothing
# 75            9,90 €      clothing
# 76            4,80 €      clothing
# 77           13,28 €      clothing
# 78            5,18 €      clothing
# 79           11,10 €      clothing
# 80           24,45 €      clothing
# 81           36,00 €          shoe
# 82            6,00 €      clothing
# 83            4,53 €      clothing
#
#                                                 sizes            sku  \
# 0       [5a, 6a, 7a, 8a, 9a, 10a, 11a, 12a, 13a, 14a]  NA823F0VH-K11
# 1                            [2a, 3a, 4a, 5a, 18-24m]  GP024G0FG-E11
# 2           [5a, 6a, 7a, 8a, 10a, 12a, 14a, 16a, 18a]  PE123J028-C11
# 3                                 [8a, 10a, 12a, 14a]  QU124L01V-K11
# 4                  [6-7a, 7-8a, 8-9a, 10-11a, 11-12a]  4BE23F082-A11
# 5   [3-4a, 4-5a, 6-7a, 7-8a, 8-9a, 10-11a, 11-12a,...  4BE24I023-K15
# 6                        [4-6m, 7-9m, 10-12m, 13-18m]  STF24C00P-T11
# 7    [4-5a, 6-7a, 7-8a, 8-9a, 10-11a, 11-12a, 13-14a]  4BE23F083-I11
# 8                                     [12a, 14a, 16a]  STF23K018-C11
# 9   [3-4a, 4-5a, 6-7a, 7-8a, 8-9a, 10-11a, 11-12a,...  4BE23G0DU-K11
# 10  [3-4a, 4-5a, 6-7a, 7-8a, 8-9a, 10-11a, 11-12a,...  4BE23G0DU-A11
# 11              [6-8a, 8-10a, 10-12a, 12-13a, 13-15a]  N1243G09Y-G11
# 12                                     [2a/5a, 6a/9a]  LA253M003-K11
# 13   [28, 28.5, 29.5, 30, 31.5, 32, 33, 33.5, 34, 35]  NI114D0A9-C11
# 14                                            [6-12m]  N1243K0B0-Q11
# 15                       [2a, 3a, 4a, 5a, 6a, 7a, 8a]  ES123A099-G11
# 16                                         [One Size]  SUF53I000-E11
# 17  [3-4a, 4-5a, 6-7a, 7-8a, 8-9a, 10-11a, 11-12a,...  4BE24A05P-H11
# 18                              [7-8a, 9-10a, 11-12a]  RI923G01Y-A11
# 19              [6-8a, 8-10a, 10-12a, 12-13a, 13-15a]  N1243G09X-Q11
# 20              [7-8a, 9-10a, 11-12a, 13-14a, 15-16a]  BE024B00K-K11
# 21                               [10a, 12a, 14a, 16a]  RG524K00Q-C11
# 22                         [11a-12a, 13a-14a, 9a-10a]  L0423J00N-B11
# 23                    [8-10a, 10-12a, 12-13a, 13-15a]  N1243E0KJ-K12
# 24                                 [2-3a, 3-4a, 4-5a]  RI923D02C-A11
# 25      [2-3a, 3-4a, 4-5a, 5-6a, 7-8a, 9-10a, 11-12a]  PO923F02X-A12
# 26                   [12-18m, 18-24m, 24-30m, 30-36m]  OV024G0AC-C11
# 27              [7-8a, 9-10a, 11-12a, 13-14a, 15-16a]  AD543G08G-C11
# 28  [3-4a, 4-5a, 6-7a, 7-8a, 8-9a, 10-11a, 11-12a,...  4BE23L04D-K11
# 29                   [32, 33, 34, 35, 36, 37, 38, 39]  PE113D00C-A11
# ..                                                ...            ...
# 54             [17, 18.5, 19.5, 21, 22, 23.5, 25, 26]  N1243A0PN-C13
# 55  [27.5, 28, 28.5, 29.5, 30, 31, 31.5, 32, 33, 3...  NI114D04L-Q11
# 56      [122/128, 134/140, 146/152, 158/164, 170/176]  F5723K022-E11
# 57                                [3-6m, 6-9m, 9-12m]  PO224D033-A11
# 58            [2a, 3y, 4a, 5a, 6a, 8a, 10a, 12a, 14a]  LA224K00X-K11
# 59       [110/116, 122/128, 134/140, 146/152, 98/104]  F5723G04A-I11
# 60                   [36, 38, 36 2/3, 37 1/3, 38 2/3]  AD116D0JK-J11
# 61              [6-8a, 8-10a, 10-12a, 12-13a, 13-15a]  N1243D11U-Q11
# 62      [110/116, 134/140, 146/152, 158/164, 170/176]  F5723K024-I11
# 63  [3-4a, 4-5a, 6-7a, 7-8a, 8-9a, 10-11a, 11-12a,...  4BE24B03K-N11
# 64          [1-3m, 3-6m, 6-9m, 9-12m, 12-18m, 18-24m]  4BE24G0CE-K11
# 65                           [2a, 3a, 4a, 5a, 6a, 7a]  NA823L0BT-K11
# 66                                   [17, 18, 19, 20]  CO413A01B-A11
# 67                     [4-5a, 5-6a, 6-7a, 7-8a, 8-9a]  OV023F03F-G11
# 68  [11a/12a, 13a/14a, 15a/16a, 5a/6a, 7a/8a, 9a/10a]  A0F23G039-K11
# 69                                [8a, 10a, 12a, 14a]  PE124L03A-K11
# 70               [5-6a, 7-8a, 11-12a, 13-14a, 15-16a]  C7643G02Q-H11
# 71                           [8a, 10a, 12a, 14a, 16a]  RJ223A01E-K11
# 72                       [9-10a, 11-12a, 13-14a, 15a]  TO223G0F5-J11
# 73           [10a/12a, 12a/14a, 4a/6a, 6a/8a, 8a/10a]  MM723C006-K11
# 74                              [4a/5a, 6a/7a, 8a/9a]  ES124G0HK-A11
# 75                    [9-10a, 11-12a, 13-14a, 15-16a]  NA823K0E0-C11
# 76                                       [4a, 6a, 8a]  ES124G0IA-M11
# 77         [11a/12a, 13a/14a, 15a/16a, 7a/8a, 9a/10a]  A0F23K00Z-G11
# 78                               [4a, 5a, 6a, 7a, 8a]  BL823F070-J11
# 79                 [15-16a, 11a-12a, 13a-14a, 9a-10a]  L0424K00Y-K11
# 80                    [8-10a, 10-12a, 12-13a, 13-15a]  N1243G022-C11
# 81                 [35.5, 36, 36.5, 37.5, 38, 39, 40]  NS414D005-K23
# 82               [6-7a, 8-9a, 10-11a, 12-13a, 14-16a]  GP024G0EZ-C11
# 83                                 [3-4a, 4-5a, 5-6a]  OU524G03D-E11
#
#                                               url_key
# 0   name-it-dress-campmini-robe-en-jersey-dark-sap...
# 1             gap-march-t-shirt-imprime-gp024g0fg-e11
# 2   pepe-jeans-patsie-pullover-grey-marl-pe123j028...
# 3          quiksilver-veste-dhiver-navy-qu124l01v-k11
# 4   benetton-dress-robe-en-jersey-whiteblack-4be23...
# 5                 benetton-chemise-blue-4be24i023-k15
# 6   staccato-bermudas-2-pack-short-indigo-structur...
# 7         benetton-dress-robe-en-jersey-4be23f083-i11
# 8   staccato-hoodie-sweatshirt-grey-melange-stf23k...
# 9                   benetton-basic-polo-4be23g0du-k11
# 10                  benetton-basic-polo-4be23g0du-a11
# 11  nike-performance-hoodie-veste-en-sweat-zippee-...
# 12        lacoste-boy-chapeau-navy-blue-la253m003-k11
# 13  nike-sportswear-md-runner-2-baskets-basses-ni1...
# 14  nike-performance-air-max-bodysuit-bootie-set-s...
# 15    esprit-pants-jean-slim-watermelon-es123a099-g11
# 16  sunnylife-giraffe-kids-lunch-bag-sac-a-main-ye...
# 17    benetton-trousers-basic-jean-slim-4be24a05p-h11
# 18            river-island-blouse-white-ri923g01y-a11
# 19  nike-performance-air-hoodie-veste-en-sweat-zip...
# 20  blue-effect-boys-pantalon-de-survetement-nacht...
# 21                re-gen-teens-pullover-rg524k00q-c11
# 22  lmtd-nlfdamier-o-neck-sweatshirt-moonbeam-l042...
# 23  nike-performance-dry-academy-pant-pantalon-de-...
# 24  river-island-pantalon-de-survetement-white-ri9...
# 25  3-pommes-dress-manches-robe-dete-broken-white-...
# 26               ovs-stripes-polo-righe-ov024g0ac-c11
# 27  adidas-performance-sweatshirt-medium-grey-heat...
# 28  benetton-jacket-basic-veste-dhiver-dark-blue-4...
# 29  pepe-jeans-belle-hearth-baskets-basses-white-p...
# ..                                                ...
# 54  nike-performance-revolution-4-chaussures-de-ru...
# 55  nike-sportswear-baskets-basses-black-ni114d04l...
# 56     friboo-sweatshirt-mineral-yellow-f5723k022-e11
# 57  polo-ralph-lauren-stripe-one-piece-combinaison...
# 58  lacoste-boy-sweatshirt-salvianavy-bluesilver-c...
# 59  friboo-go-for-it-t-shirt-imprime-orchid-bouque...
# 60  adidas-originals-campus-baskets-basses-ad116d0...
# 61  nike-performance-cr7-dry-t-shirt-de-sport-blac...
# 62  friboo-no-rules-crop-hoody-sweatshirt-purple-w...
# 63  benetton-trousers-basic-chino-khaki-4be24b03k-n11
# 64        benetton-t-shirt-imprime-blue-4be24g0ce-k11
# 65  name-it-nmfmello-jacket-unicornsmini-veste-mi-...
# 66  converse-first-star-chaussons-pour-bebe-co413a...
# 67  ovs-striped-dress-girl-robe-en-jersey-chinese-...
# 68  abercrombie-and-fitch-graphic-t-shirt-a-manche...
# 69   pepe-jeans-brandon-veste-mi-saison-pe124l03a-k11
# 70  champion-american-classics-hooded-veste-en-swe...
# 71  retour-jeans-zita-jeans-skinny-medium-blue-rj2...
# 72  tom-tailor-placed-print-t-shirt-a-manches-long...
# 73  mini-molly-star-girls-short-navy-blue-mm723c00...
# 74         esprit-t-shirt-imprime-white-es124g0hk-a11
# 75       name-it-sweatshirt-sky-captain-na823k0e0-c11
# 76    esprit-t-shirt-imprime-soft-green-es124g0ia-m11
# 77  abercrombie-and-fitch-colorblock-crew-sweatshi...
# 78     blue-seven-robe-en-jersey-azalee-bl823f070-j11
# 79  lmtd-nlmrami-sweatshirt-sky-captain-l0424k00y-k11
# 80     nike-performance-ya76-sweatshirt-n1243g022-c11
# 81  nike-sb-stefan-janoski-chaussures-de-skate-ns4...
# 82      gap-boys-henley-t-shirt-imprime-gp024g0ez-c11
# 83  outfit-kids-this-kids-got-skills-tee-t-shirt-i...
#
# [84 rows x 17 columns]

# %% [markdown]
# #### Collect all the objects from selected filters. Total number of pages can be found in the same json. Use *sku* column as index.
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having family_articles, flags, media and sizes remaining lists (they are exceptions).

# %%
# Get the total number of pages
total_pages=results['pagination']['page_count']

# Your code
df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset={k}&sort=sale'
    response = requests.get(url, headers = header)
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)

df
df2=df.copy

# %% [markdown]
# #### Display the trending brand in DataFrame

# %%
df.brand_name.value_counts()
# Out:
# Friboo                 906
# OVS                    783
# Name it                685
# Benetton               581
# GAP                    578
# Esprit                 483
# Nike Performance       398
# adidas Performance     375
# River Island           367
# s.Oliver               360
# Tommy Hilfiger         346
# Puma                   336
# Polo Ralph Lauren      316
# Carter's               275
# Molo                   258
# Pepe Jeans             254
# Naturino               250
# Abercrombie & Fitch    250
# Petrol Industries      243
# Staccato               237
# mothercare             230
# Blue Seven             229
# Noppies                217
# Cotton On              208
# J.CREW                 207
# adidas Originals       193
# Nike Sportswear        192
# Vingino                169
# Converse               166
# Sanetta                161
#                       ...
# Kempa                    3
# Merrell                  3
# Joma                     3
# MAÁ                      3
# OppoSuits                3
# Save the duck            3
# Dr. Martens              3
# K-SWISS                  2
# Dockers by Gerli         2
# Zip and Zoe              2
# Sorel                    2
# Sunseeker                2
# Teva                     2
# Saucony                  2
# Schmuddelwedda           2
# Flower Mountain          2
# Reusch                   1
# Tobias & The Bear        1
# Herschel                 1
# Dreimaster               1
# Uhlsport                 1
# Chiemsee                 1
# Deuter                   1
# Flik Flak                1
# Hawkers                  1
# Reima                    1
# Arena                    1
# ODLO                     1
# Fabrizio                 1
# Minymo                   1
# Name: brand_name, Length: 307, dtype: int64

# %%
df.brand_name.value_counts().index[0]
# Out:
# 'Friboo'

# %% [markdown]
# #### Display the brand with maximal total discount (sum of discounts on all goods)

# %%
df.head()
# Out:
#               amount        brand_name  \
# sku
# N1243E0J0-Q11    NaN  Nike Performance
# NI114D0A1-C11    NaN   Nike Sportswear
# N1243A0XZ-C11   82 g  Nike Performance
# N1243G01D-N11    NaN  Nike Performance
# NI114D0A1-C12    NaN   Nike Sportswear
#
#                                                  family_articles  \
# sku
# N1243E0J0-Q11  [{'sku': 'N1243E0J0-Q11', 'url_key': 'nike-per...
# NI114D0A1-C11  [{'sku': 'NI114D0A1-C11', 'url_key': 'nike-spo...
# N1243A0XZ-C11  [{'sku': 'N1243A0XZ-C11', 'url_key': 'nike-per...
# N1243G01D-N11  [{'sku': 'N1243G01D-N11', 'url_key': 'nike-per...
# NI114D0A1-C12  [{'sku': 'NI114D0A1-C12', 'url_key': 'nike-spo...
#
#                                                            flags  is_premium  \
# sku
# N1243E0J0-Q11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# NI114D0A1-C11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# N1243A0XZ-C11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# N1243G01D-N11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# NI114D0A1-C12  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
#
#                                                            media  \
# sku
# N1243E0J0-Q11  [{'path': 'N1/24/3E/0J/0Q/11/N1243E0J0-Q11@4.j...
# NI114D0A1-C11  [{'path': 'NI/11/4D/0A/1C/11/NI114D0A1-C11@8.j...
# N1243A0XZ-C11  [{'path': 'N1/24/3A/0X/ZC/11/N1243A0XZ-C11@9.j...
# N1243G01D-N11  [{'path': 'N1/24/3G/01/DN/11/N1243G01D-N11@4.j...
# NI114D0A1-C12  [{'path': 'NI/11/4D/0A/1C/12/NI114D0A1-C12@7.j...
#
#                                                             name  \
# sku
# N1243E0J0-Q11         AIR PANT - Pantalon de survêtement - black
# NI114D0A1-C11  REACT PRESTO - Baskets basses - wolf grey/blac...
# N1243A0XZ-C11  FLEX RUNNER - Chaussures de running neutres - ...
# N1243G01D-N11  FULL ZIP - veste en sweat zippée - cargo khaki...
# NI114D0A1-C12    REACT PRESTO - Baskets basses - wolf grey/white
#
#                price.has_different_original_prices  \
# sku
# N1243E0J0-Q11                                False
# NI114D0A1-C11                                False
# N1243A0XZ-C11                                False
# N1243G01D-N11                                False
# NI114D0A1-C12                                False
#
#                price.has_different_prices  \
# sku
# N1243E0J0-Q11                        True
# NI114D0A1-C11                        True
# N1243A0XZ-C11                       False
# N1243G01D-N11                       False
# NI114D0A1-C12                        True
#
#                price.has_different_promotional_prices  \
# sku
# N1243E0J0-Q11                                    True
# NI114D0A1-C11                                    True
# N1243A0XZ-C11                                   False
# N1243G01D-N11                                   False
# NI114D0A1-C12                                    True
#
#                price.has_discount_on_selected_sizes_only price.original  \
# sku
# N1243E0J0-Q11                                      False        44,95 €
# NI114D0A1-C11                                      False        94,95 €
# N1243A0XZ-C11                                      False        29,95 €
# N1243G01D-N11                                      False        39,95 €
# NI114D0A1-C12                                      False        94,95 €
#
#               price.promotional product_group  \
# sku
# N1243E0J0-Q11           13,49 €      clothing
# NI114D0A1-C11           38,00 €          shoe
# N1243A0XZ-C11           18,00 €          shoe
# N1243G01D-N11           16,00 €      clothing
# NI114D0A1-C12           38,00 €          shoe
#
#                                                   sizes  \
# sku
# N1243E0J0-Q11     [6-8a, 8-10a, 10-12a, 12-13a, 13-15a]
# NI114D0A1-C11  [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40]
# N1243A0XZ-C11    [17, 18.5, 19.5, 21, 22, 23.5, 25, 26]
# N1243G01D-N11           [8-10a, 10-12a, 12-13a, 13-15a]
# NI114D0A1-C12  [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40]
#
#                                                          url_key
# sku
# N1243E0J0-Q11  nike-performance-air-pant-pantalon-de-survetem...
# NI114D0A1-C11  nike-sportswear-react-presto-baskets-basses-ni...
# N1243A0XZ-C11  nike-performance-flex-runner-chaussures-de-run...
# N1243G01D-N11  nike-performance-ya76-veste-en-sweat-n1243g01d...
# NI114D0A1-C12  nike-sportswear-react-presto-baskets-basses-ni...

# %%
#Our data is still text. Convert prices into numbers:
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount

# %%
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'Friboo'

# %% [markdown]
# #### Display the brands without discount at all

# %%
total_disc[total_disc==0]
# Out:
# Series([], Name: discount_amount, dtype: float64)
