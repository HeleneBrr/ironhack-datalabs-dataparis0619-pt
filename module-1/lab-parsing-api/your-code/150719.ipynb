# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
#endpoint = url

# your code here
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
url='https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=84&sort=sale'

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
header = {'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36'}

response = requests.get(url, headers =header)
results = response.json()
results


flattened_data = json_normalize(results)

flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1

# FIND OUT THE TOTAL PAGE COUNT IN THE 1ST PAGE DATA
total_pages=results['pagination']['page_count']

# Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    #le f montre que le k va changer à chaque fois
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset={k}&sort=sale'
    response = requests.get(url, headers = header)
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)

1df
# Out:
#               amount         brand_name  \
# sku
# NI114D09A-Q13    NaN    Nike Sportswear
# N1243D11U-Q11    NaN   Nike Performance
# N1243L00A-Q11    NaN   Nike Performance
# N1243E0J0-Q11    NaN   Nike Performance
# NI114D0A1-C11    NaN    Nike Sportswear
# N1243A0XZ-C11   82 g   Nike Performance
# N1243G01D-N11    NaN   Nike Performance
# NI114D0A1-C12    NaN    Nike Sportswear
# F5723K01F-G11    NaN             Friboo
# R2724G00L-N11    NaN           Redskins
# RE016D03K-A11    NaN     Reebok Classic
# N1243G09R-Q11    NaN   Nike Performance
# 4BE23F089-J11    NaN           Benetton
# NI114D0AG-A11    NaN    Nike Sportswear
# TO114D01B-K11    NaN     Tommy Hilfiger
# N1243F049-Q11    NaN   Nike Performance
# N1243I02D-B11    NaN   Nike Performance
# N1243E0JD-Q13    NaN   Nike Performance
# QU124G066-Q11    NaN         Quiksilver
# N1243G022-N11    NaN   Nike Performance
# NI114D057-Q11    NaN    Nike Sportswear
# GRF23E001-G11    NaN              Grunt
# ...

# %%
# On prend que 5 pages sinon ça bug

df2=pd.DataFrame()
for i in range(5):
    k=84*i
    #le f montre que le k va changer à chaque fois
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset={k}&sort=sale'
    response = requests.get(url, headers = header)
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df2 = df.append(flattened_data1)

df2
# Out:
#               amount           brand_name  discount_amount  \
# sku
# N1243D11U-Q11    NaN     Nike Performance         0.200401
# NI114D09A-Q13    NaN      Nike Sportswear         0.399800
# N1243L00A-Q11    NaN     Nike Performance         0.300143
# N1243E0J0-Q11    NaN     Nike Performance         0.699889
# PU113F00E-Q11    NaN                 Puma         0.700637
# N1243A0XZ-C11   82 g     Nike Performance         0.398998
# N1243G01D-N11    NaN     Nike Performance         0.599499
# NI114D0A1-C12    NaN      Nike Sportswear         0.599789
# F5723K01F-G11    NaN               Friboo         0.699164
# RE016D03K-A11    NaN       Reebok Classic         0.649708
# N1243G09R-Q11    NaN     Nike Performance         0.599555
# 4BE23F089-J11    NaN             Benetton         0.699807
# NI114D0AG-A11    NaN      Nike Sportswear         0.299500
# CO423G018-A11    NaN             Converse         0.699857
# TO114D01B-K11    NaN       Tommy Hilfiger         0.300077
# ...

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
#Trending brand:
df.brand_name.value_counts().index[0]
# Out:
# 'Nike Performance'

# %%
# The product(s) with the highest discount.
df2['price.original']=df2['price.original'].str.extract('(\d*,\d*)')
df2['price.promotional']=df2['price.promotional'].str.extract('(\d*,\d*)')

df2['price.original'] = [x.replace(',', '.') for x in df2['price.original']]
df2['price.promotional'] = [x.replace(',', '.') for x in df2['price.promotional']]

df2['discount_amount']=(df2['price.original'].astype(float)-df2['price.promotional'].astype(float))/(df2['price.original'].astype(float))

df2['discount_amount'].sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-d258ae904e2b> in <module>
#       3 df2['price.promotional']=df2['price.promotional'].str.extract('(\d*,\d*)')
#       4
# ----> 5 df2['price.original'] = [x.replace(',', '.') for x in df2['price.original']]
#       6 df2['price.promotional'] = [x.replace(',', '.') for x in df2['price.promotional']]
#       7
#
# <ipython-input-80-d258ae904e2b> in <listcomp>(.0)
#       3 df2['price.promotional']=df2['price.promotional'].str.extract('(\d*,\d*)')
#       4
# ----> 5 df2['price.original'] = [x.replace(',', '.') for x in df2['price.original']]
#       6 df2['price.promotional'] = [x.replace(',', '.') for x in df2['price.promotional']]
#       7
#
# AttributeError: 'float' object has no attribute 'replace'

# %%
#On voudrait afficher les noms de produits et pas les sku hors on a un problème car il y a des duplicata
df.index.duplicated().any()
df3 = df[~df.index.duplicated()]
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20148 entries, NI114D09A-Q13 to STF26J003-C11
# Data columns (total 20 columns):
# amount                                          183 non-null object
# brand_name                                      20148 non-null object
# family_articles                                 20148 non-null object
# flags                                           20148 non-null object
# is_premium                                      20148 non-null bool
# media                                           20148 non-null object
# name                                            20148 non-null object
# price.has_different_original_prices             20148 non-null bool
# price.has_different_prices                      20148 non-null bool
# price.has_different_promotional_prices          20148 non-null bool
# price.has_discount_on_selected_sizes_only       20148 non-null bool
# price.original                                  20148 non-null object
# ...

# %%
#???
sorted_disc_amount = df3['discount_amount'].sort_values(ascending=False)
pd.concat([sorted_disc_amount, df3.name], axis=1)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#                discount_amount  \
# 10K43A025-E11         0.250660
# 10K43A025-J11         0.400000
# 10K43A025-K12         0.200528
# 10K43A025-K13         0.250660
# 10K43A025-Q11         0.200528
# 10K43A025-Q14         0.300264
# 10K43A02E-Q12         0.300143
# 10K43A02R-C11         0.198397
# 10K43A02Y-K12         0.200000
# 10K43A02Y-K13         0.102902
# 10K43A03D-B11         0.299124
# 10K43A03G-Q11         0.097744
# 10K43A03J-G11         0.200358
# 10K43A03O-J12         0.200528
# 10K43A046-Q13         0.200358
# 10K43A04B-K11         0.200000
# 10K43A04D-K11         0.200303
# 10K43A04E-K11         0.200303
# 10K43B01A-K11         0.200000
# ...

# %%
# The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices
df2['discount_amount_f']= pd.to_numeric(df2['discount_amount'])
df2['price_original_f']= pd.to_numeric(df2['price.original'],errors='coerce')
sum_discounts_all = sum(df2['discount_amount_f'])/sum(df2['price.original_f'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price.original_f'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-0dab221f8265> in <module>
# ...

# %%
df2['price.original']=df2['price.original'].str.extract('(\d*,\d*)')
df2['price.promotional']=df2['price.promotional'].str.extract('(\d*,\d*)')

df2['price.original'] = [x.replace(',', '.') for x in df2['price.original']]
df2['price.promotional'] = [x.replace(',', '.') for x in df2['price.promotional']]

df2['discount_amount']=(df2['price.original'].astype(float)-df2['price.promotional'].astype(float))/(df2['price.original'].astype(float))

df2['discount_amount'].sort_values(ascending=False)
